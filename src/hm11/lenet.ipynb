# %%
# cài bộ thư viện d2l
# !pip install d2l==0.16.5
# Out:
# Collecting d2l==0.16.5
#   Downloading d2l-0.16.5-py3-none-any.whl.metadata (346 bytes)
# Requirement already satisfied: jupyter in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from d2l==0.16.5) (1.0.0)
# Requirement already satisfied: numpy in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from d2l==0.16.5) (1.23.5)
# Requirement already satisfied: matplotlib in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from d2l==0.16.5) (3.7.2)
# Requirement already satisfied: requests in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from d2l==0.16.5) (2.31.0)
# Requirement already satisfied: pandas in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from d2l==0.16.5) (2.0.3)
# Requirement already satisfied: notebook in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from jupyter->d2l==0.16.5) (7.3.3)
# Requirement already satisfied: qtconsole in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from jupyter->d2l==0.16.5) (5.6.1)
# Requirement already satisfied: jupyter-console in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from jupyter->d2l==0.16.5) (6.6.3)
# Requirement already satisfied: nbconvert in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from jupyter->d2l==0.16.5) (7.16.6)
# Requirement already satisfied: ipykernel in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from jupyter->d2l==0.16.5) (6.29.5)
# Requirement already satisfied: ipywidgets in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from jupyter->d2l==0.16.5) (8.1.7)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from matplotlib->d2l==0.16.5) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from matplotlib->d2l==0.16.5) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from matplotlib->d2l==0.16.5) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from matplotlib->d2l==0.16.5) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from matplotlib->d2l==0.16.5) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from matplotlib->d2l==0.16.5) (10.4.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from matplotlib->d2l==0.16.5) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from matplotlib->d2l==0.16.5) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from matplotlib->d2l==0.16.5) (6.4.5)
# Requirement already satisfied: pytz>=2020.1 in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from pandas->d2l==0.16.5) (2025.2)
# Requirement already satisfied: tzdata>=2022.1 in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from pandas->d2l==0.16.5) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from requests->d2l==0.16.5) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from requests->d2l==0.16.5) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from requests->d2l==0.16.5) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from requests->d2l==0.16.5) (2024.8.30)
# Requirement already satisfied: zipp>=3.1.0 in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from importlib-resources>=3.2.0->matplotlib->d2l==0.16.5) (3.20.2)
# Requirement already satisfied: six>=1.5 in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib->d2l==0.16.5) (1.16.0)
# Requirement already satisfied: appnope in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from ipykernel->jupyter->d2l==0.16.5) (0.1.4)
# Requirement already satisfied: comm>=0.1.1 in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from ipykernel->jupyter->d2l==0.16.5) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from ipykernel->jupyter->d2l==0.16.5) (1.8.16)
# Requirement already satisfied: ipython>=7.23.1 in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from ipykernel->jupyter->d2l==0.16.5) (8.12.3)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from ipykernel->jupyter->d2l==0.16.5) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from ipykernel->jupyter->d2l==0.16.5) (5.8.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from ipykernel->jupyter->d2l==0.16.5) (0.1.6)
# Requirement already satisfied: nest-asyncio in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from ipykernel->jupyter->d2l==0.16.5) (1.6.0)
# Requirement already satisfied: psutil in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from ipykernel->jupyter->d2l==0.16.5) (7.0.0)
# Requirement already satisfied: pyzmq>=24 in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from ipykernel->jupyter->d2l==0.16.5) (27.0.1)
# Requirement already satisfied: tornado>=6.1 in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from ipykernel->jupyter->d2l==0.16.5) (6.4.2)
# Requirement already satisfied: traitlets>=5.4.0 in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from ipykernel->jupyter->d2l==0.16.5) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from ipywidgets->jupyter->d2l==0.16.5) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from ipywidgets->jupyter->d2l==0.16.5) (3.0.15)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from jupyter-console->jupyter->d2l==0.16.5) (3.0.51)
# Requirement already satisfied: pygments in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from jupyter-console->jupyter->d2l==0.16.5) (2.19.2)
# Requirement already satisfied: beautifulsoup4 in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from nbconvert->jupyter->d2l==0.16.5) (4.13.4)
# Requirement already satisfied: bleach!=5.0.0 in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter->d2l==0.16.5) (6.1.0)
# Requirement already satisfied: defusedxml in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from nbconvert->jupyter->d2l==0.16.5) (0.7.1)
# Requirement already satisfied: importlib-metadata>=3.6 in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from nbconvert->jupyter->d2l==0.16.5) (7.0.1)
# Requirement already satisfied: jinja2>=3.0 in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from nbconvert->jupyter->d2l==0.16.5) (3.1.6)
# Requirement already satisfied: jupyterlab-pygments in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from nbconvert->jupyter->d2l==0.16.5) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from nbconvert->jupyter->d2l==0.16.5) (2.1.3)
# Requirement already satisfied: mistune<4,>=2.0.3 in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from nbconvert->jupyter->d2l==0.16.5) (3.1.3)
# Requirement already satisfied: nbclient>=0.5.0 in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from nbconvert->jupyter->d2l==0.16.5) (0.10.1)
# Requirement already satisfied: nbformat>=5.7 in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from nbconvert->jupyter->d2l==0.16.5) (5.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from nbconvert->jupyter->d2l==0.16.5) (1.5.1)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from notebook->jupyter->d2l==0.16.5) (2.14.2)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from notebook->jupyter->d2l==0.16.5) (2.27.3)
# Requirement already satisfied: jupyterlab<4.4,>=4.3.6 in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from notebook->jupyter->d2l==0.16.5) (4.3.8)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from notebook->jupyter->d2l==0.16.5) (0.2.4)
# Requirement already satisfied: qtpy>=2.4.0 in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from qtconsole->jupyter->d2l==0.16.5) (2.4.3)
# Requirement already satisfied: webencodings in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter->d2l==0.16.5) (0.5.1)
# Requirement already satisfied: tinycss2<1.3,>=1.1.0 in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter->d2l==0.16.5) (1.2.1)
# Requirement already satisfied: backcall in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->jupyter->d2l==0.16.5) (0.2.0)
# Requirement already satisfied: decorator in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->jupyter->d2l==0.16.5) (5.2.1)
# Requirement already satisfied: jedi>=0.16 in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->jupyter->d2l==0.16.5) (0.19.2)
# Requirement already satisfied: pickleshare in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->jupyter->d2l==0.16.5) (0.7.5)
# Requirement already satisfied: stack-data in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->jupyter->d2l==0.16.5) (0.6.3)
# Requirement already satisfied: typing-extensions in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->jupyter->d2l==0.16.5) (4.8.0)
# Requirement already satisfied: pexpect>4.3 in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->jupyter->d2l==0.16.5) (4.9.0)
# Requirement already satisfied: platformdirs>=2.5 in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter->d2l==0.16.5) (3.10.0)
# Requirement already satisfied: anyio>=3.1.0 in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->d2l==0.16.5) (4.5.2)
# Requirement already satisfied: argon2-cffi>=21.1 in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->d2l==0.16.5) (25.1.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->d2l==0.16.5) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->d2l==0.16.5) (0.5.3)
# Requirement already satisfied: overrides>=5.0 in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->d2l==0.16.5) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->d2l==0.16.5) (0.21.1)
# Requirement already satisfied: send2trash>=1.8.2 in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->d2l==0.16.5) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->d2l==0.16.5) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->d2l==0.16.5) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from jupyterlab<4.4,>=4.3.6->notebook->jupyter->d2l==0.16.5) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from jupyterlab<4.4,>=4.3.6->notebook->jupyter->d2l==0.16.5) (0.28.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from jupyterlab<4.4,>=4.3.6->notebook->jupyter->d2l==0.16.5) (2.2.6)
# Requirement already satisfied: setuptools>=41.1.0 in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from jupyterlab<4.4,>=4.3.6->notebook->jupyter->d2l==0.16.5) (75.1.0)
# Requirement already satisfied: tomli>=1.2.2 in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from jupyterlab<4.4,>=4.3.6->notebook->jupyter->d2l==0.16.5) (2.2.1)
# Requirement already satisfied: babel>=2.10 in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from jupyterlab-server<3,>=2.27.1->notebook->jupyter->d2l==0.16.5) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from jupyterlab-server<3,>=2.27.1->notebook->jupyter->d2l==0.16.5) (0.12.1)
# Requirement already satisfied: jsonschema>=4.18.0 in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from jupyterlab-server<3,>=2.27.1->notebook->jupyter->d2l==0.16.5) (4.23.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from nbformat>=5.7->nbconvert->jupyter->d2l==0.16.5) (2.21.2)
# Requirement already satisfied: wcwidth in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter->d2l==0.16.5) (0.2.13)
# Requirement already satisfied: soupsieve>1.2 in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from beautifulsoup4->nbconvert->jupyter->d2l==0.16.5) (2.7)
# Requirement already satisfied: sniffio>=1.1 in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter->d2l==0.16.5) (1.3.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter->d2l==0.16.5) (1.3.0)
# Requirement already satisfied: argon2-cffi-bindings in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter->d2l==0.16.5) (21.2.0)
# Requirement already satisfied: httpcore==1.* in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from httpx>=0.25.0->jupyterlab<4.4,>=4.3.6->notebook->jupyter->d2l==0.16.5) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab<4.4,>=4.3.6->notebook->jupyter->d2l==0.16.5) (0.16.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter->d2l==0.16.5) (0.8.4)
# Requirement already satisfied: attrs>=22.2.0 in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->jupyter->d2l==0.16.5) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->jupyter->d2l==0.16.5) (2023.12.1)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10 in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->jupyter->d2l==0.16.5) (1.3.10)
# Requirement already satisfied: referencing>=0.28.4 in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->jupyter->d2l==0.16.5) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->jupyter->d2l==0.16.5) (0.20.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->d2l==0.16.5) (3.3.0)
# Requirement already satisfied: pyyaml>=5.3 in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->d2l==0.16.5) (6.0.2)
# Requirement already satisfied: rfc3339-validator in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->d2l==0.16.5) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->d2l==0.16.5) (0.1.1)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->jupyter->d2l==0.16.5) (0.7.0)
# Requirement already satisfied: executing>=1.2.0 in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->d2l==0.16.5) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->d2l==0.16.5) (3.0.0)
# Requirement already satisfied: pure-eval in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->d2l==0.16.5) (0.2.3)
# Requirement already satisfied: fqdn in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->d2l==0.16.5) (1.5.1)
# Requirement already satisfied: isoduration in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->d2l==0.16.5) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->d2l==0.16.5) (3.0.0)
# Requirement already satisfied: uri-template in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->d2l==0.16.5) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->d2l==0.16.5) (24.8.0)
# Requirement already satisfied: cffi>=1.0.1 in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter->d2l==0.16.5) (1.17.1)
# Requirement already satisfied: pycparser in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter->d2l==0.16.5) (2.21)
# Requirement already satisfied: arrow>=0.15.0 in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->d2l==0.16.5) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /Users/miniconda3/envs/d2l/lib/python3.8/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->d2l==0.16.5) (2.9.0.20241206)
# Downloading d2l-0.16.5-py3-none-any.whl (77 kB)
# Installing collected packages: d2l
#   Attempting uninstall: d2l
#     Found existing installation: d2l 1.0.3
#     Uninstalling d2l-1.0.3:
#       Successfully uninstalled d2l-1.0.3
# Successfully installed d2l-0.16.5

# %% [markdown]
# # Convolutional Neural Networks (LeNet)
#
# Bây giờ ta đã sẵn sàng kết hợp tất cả các công cụ lại với nhau để triển khai mạng nơ-ron tích chập hoàn chỉnh. Trong lần trước, chúng ta đã áp dụng softmax regression và một perceptron đa tầng cho ảnh quần áo trong bộ dữ liệu Fashion-MNIST.
#
# Để tương thích với đầu vào dạng vector một chiều với độ dài cố định của các perceptron đa tầng, đầu tiên ta trải phẳng từng hình ảnh và thu được các vector có chiều dài 784, trước khi xử lý chúng với một chuỗi các tầng kết nối đầy đủ.
#
# Bây giờ đã có các tầng tích chập, ta có thể giữ nguyên ảnh đầu vào ở dạng không gian hai chiều như ảnh gốc và xử lý chúng với một chuỗi các tầng tích chập liên tiếp. Hơn nữa, vì ta đang sử dụng các tầng tích chập, số lượng tham số cần thiết sẽ giảm đi đáng kể.
#
# Trong phần này, chúng tôi sẽ giới thiệu một trong những mạng nơ-ron tích chập được công bố đầu tiên. Ưu điểm của mạng tích chập được minh hoạ lần đầu bởi Yann Lecun (lúc đó đang nghiên cứu tại AT&T Bell Labs) với ứng dụng nhận dạng các số viết tay trong ảnh-LeNet5. Vào những năm 90, các thí nghiệm của các nhà nghiên cứu với LeNet đã đưa ra bằng chứng thuyết phục đầu tiên về tính khả thi của việc huấn luyện mạng nơ-ron tích chập bằng lan truyền ngược. Mô hình của họ đã đạt được kết quả rất tốt (chỉ có Máy Vector Hỗ trợ — SVM tại thời điểm đó là có thể sánh bằng) và đã được đưa vào sử dụng để nhận diện các chữ số khi xử lý tiền gửi trong máy ATM. Một số máy ATM vẫn chạy các đoạn mã mà Yann và đồng nghiệp Leon Bottou đã viết vào những năm 1990!
#
#
# ## LeNet
#
# Có thể coi đơn giản LeNet gồm 2 phần :
#
# (i) một khối các tầng tích chập
#
# (ii) một khối các tầng kết nối đầy đủ
#
# ![Data flow in LeNet. The input is a handwritten digit, the output a probability over 10 possible outcomes.](http://d2l.ai/_images/lenet.svg)
# <!-- :label:`img_lenet` -->
#
# Các đơn vị cơ bản trong khối tích chập là một tầng tích chập và một lớp gộp trung bình theo sau (lưu ý rằng gộp cực đại hoạt động tốt hơn, nhưng nó chưa được phát minh vào những năm 90). Tầng tích chập được sử dụng để nhận dạng các mẫu không gian trong ảnh, chẳng hạn như các đường cạnh và các bộ phận của vật thể, lớp gộp trung bình phía sau được dùng để giảm số chiều. Khối tầng tích chập tạo nên từ việc xếp chồng các khối nhỏ gồm hai đơn vị cơ bản này. Mỗi tầng tích chập sử dụng kernel size có kích thước  5×5  và xử lý mỗi đầu ra với một hàm kích hoạt sigmoid (ReLU hiện được biết là hoạt động đáng tin cậy hơn, nhưng chưa được phát minh vào thời điểm đó!). Tầng tích chập đầu tiên có 6 kênh đầu ra và tầng tích chập thứ hai tăng độ sâu kênh hơn nữa lên 16.
#
# Tuy nhiên, cùng với sự gia tăng số lượng kênh này, chiều cao và chiều rộng lại giảm đáng kể. Do đó, việc tăng số lượng kênh đầu ra làm cho kích thước tham số của hai tầng tích chập tương tự nhau. Hai lớp gộp trung bình có kích thước  2×2  và sải bước bằng 2 (điều này có nghĩa là chúng không chồng chéo). Nói cách khác, lớp gộp giảm kích thước của các biểu diễn còn một phần tư kích thước trước khi gộp.
#
# Đầu ra của khối tích chập có kích thước được xác định bằng (kích thước batch, kênh, chiều cao, chiều rộng). Trước khi chuyển đầu ra của khối tích chập sang khối kết nối đầy đủ, ta phải trải phẳng từng mẫu trong minibatch. Nói cách khác, ta biến đổi đầu vào 4D thành đầu vào 2D tương thích với các tầng kết nối đầy đủ: nhắc lại, chiều thứ nhất là chỉ số các mẫu trong minibatch và chiều thứ hai là biểu diễn vector phẳng của mỗi mẫu. Khối tầng kết nối đầy đủ của LeNet có ba tầng kết nối đầy đủ, với số lượng đầu ra lần lượt là 120, 84 và 10. Bởi vì ta đang thực hiện bài toán phân loại, tầng đầu ra 10 chiều tương ứng với số lượng các lớp đầu ra khả thi (10 chữ số từ 0 đến 9).
#
# Để thực sự hiểu những gì diễn ra bên trong LeNet có thể đòi hỏi một chút nỗ lực, tuy nhiên bạn có thể thấy bên dưới đây việc lập trình Lenet bằng thư viện học sâu hiện đại rất đơn giản. Một lần nữa, ta sẽ dựa vào lớp Sequential.

# %%
import torch
from torch import nn
from d2l import torch as d2l

net = nn.Sequential(nn.Conv2d(1, 6, kernel_size=5, padding=2), nn.Sigmoid(), #padding 2 -> size (+4, +4)
                    nn.AvgPool2d(kernel_size=2, stride=2),
                    nn.Conv2d(6, 16, kernel_size=5), nn.Sigmoid(),
                    nn.AvgPool2d(kernel_size=2, stride=2), nn.Flatten(),
                    nn.Linear(16*5*5, 120), nn.Sigmoid(),
                    nn.Linear(120, 84), nn.Sigmoid(), nn.Linear(84, 10))

# %% [markdown]
# So với mạng ban đầu, ta đã thay thế kích hoạt Gauss ở tầng cuối cùng bằng một tầng kết nối đầy đủ thông thường mà thường dễ huấn luyện hơn đáng kể. Ngoại trừ điểm đó, mạng này giống với định nghĩa gốc của LeNet5.
#
# Tiếp theo, ta hãy xem một ví dụ dưới đây. Như trong hình, ta đưa vào mạng một mẫu đơn kênh kích thước  28×28  và thực hiện một lượt truyền xuôi qua các tầng và in kích thước đầu ra ở mỗi tầng để hiểu rõ những gì đang xảy ra bên trong.
#
#
# ![Compressed notation for LeNet-5.](https://github.com/d2l-ai/d2l-tensorflow-colab/blob/master/img/lenet-vert.svg?raw=1)
# <!-- :label:`img_lenet_vert` -->

# %%
X = torch.randn(size = (1, 1, 28, 28))
for layer in net:
    X = layer(X)
    print(layer.__class__.__name__, 'X shape after each layer: \t', X.shape)
# Out:
# Conv2d X shape after each layer: 	 torch.Size([1, 6, 28, 28])
# Sigmoid X shape after each layer: 	 torch.Size([1, 6, 28, 28])
# AvgPool2d X shape after each layer: 	 torch.Size([1, 6, 14, 14])
# Conv2d X shape after each layer: 	 torch.Size([1, 16, 10, 10])
# Sigmoid X shape after each layer: 	 torch.Size([1, 16, 10, 10])
# AvgPool2d X shape after each layer: 	 torch.Size([1, 16, 5, 5])
# Flatten X shape after each layer: 	 torch.Size([1, 400])
# Linear X shape after each layer: 	 torch.Size([1, 120])
# Sigmoid X shape after each layer: 	 torch.Size([1, 120])
# Linear X shape after each layer: 	 torch.Size([1, 84])
# Sigmoid X shape after each layer: 	 torch.Size([1, 84])
# Linear X shape after each layer: 	 torch.Size([1, 10])

# %% [markdown]
# chú ý rằng, chiều cao và chiều rộng của biểu diễn sau mỗi tầng trong toàn bộ khối tích chập sẽ giảm theo chiều sâu của mạng(so với chiều cao và chiều rộng của biểu diễn ở tầng trước). Tầng tích chập đầu tiên sử dụng một hạt nhân với chiều cao và chiều rộng là  5  rồi đệm thêm  2  đơn vị điểm ảnh để giữ nguyên kích thước đầu vào. Trong khi đó, tầng tích chập thứ hai cũng dùng cùng một hạt nhân với kích thước là  5×5  mà không có sử dụng giá trị đệm thêm vào, dẫn đến việc chiều cao và chiều rộng giảm đi 4 đơn vị điểm ảnh. Ngoài ra, mỗi tầng gộp sẽ làm giảm đi một nửa chiều cao và chiều rộng của đặc trưng ánh xạ đầu vào. Tuy nhiên, khi chúng ta đi theo chiều sâu của mạng, số kênh sẽ tăng lần lượt theo từng tầng. Từ 1 kênh của dữ liệu đầu vào lên tới 6 kênh sau tầng tích chập thứ nhất và 16 kênh sau tầng tích chập thứ hai. Sau đó,giảm số chiều lần lượt qua từng tầng kết nối đầy đủ đến khi trả về một đầu ra có kích thước bằng số lượng lớp của hình ảnh.
#
# ## Training

# %%
batch_size = 32
train_iter, test_iter = d2l.load_data_fashion_mnist(batch_size=batch_size)
# Out:
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz to ../data/FashionMNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 26421880/26421880 [00:08<00:00, 3224353.39it/s]
# Extracting ../data/FashionMNIST/raw/train-images-idx3-ubyte.gz to ../data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz to ../data/FashionMNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 29515/29515 [00:00<00:00, 126010.27it/s]
# Extracting ../data/FashionMNIST/raw/train-labels-idx1-ubyte.gz to ../data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz to ../data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 4422102/4422102 [00:45<00:00, 98259.39it/s]
# Extracting ../data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz to ../data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz to ../data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 5148/5148 [00:00<00:00, 11436587.39it/s]
# Extracting ../data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz to ../data/FashionMNIST/raw

# %% [markdown]
# Dù mạng tích chập có thể có số lượng tham số không lớn, chúng vẫn tiêu tốn nhiều tài nguyên tính toán hơn so với perceptron sâu đa tầng. Vì vậy, nếu có sẵn GPU, thì đây là thời điểm thích hợp để dùng nó nhằm tăng tốc quá trình huấn luyện.

# %% [markdown]
# Chúng ta cũng cần phải cập nhật hàm huấn luyện để mô hình có thể chạy được trên GPU. Chúng ta cần chuyển từng batch dữ liệu tới ngữ cảnh được chỉ định (hy vọng là GPU thay vì CPU) trước khi thực hiện lượt truyền xuôi và lượt truyền ngược.
#
# Để đơn giản khi làm việc với mạng nơ-ron có tới hàng chục tầng, hàm train_ch6 chỉ hỗ trợ các mô hình được xây dựng bằng thư viện Gluon. Để khởi tạo bộ tham số của mô hình trên thiết bị đã được chỉ định bởi ctx, ta sẽ sử dụng bộ khởi tạo Xavier. Ta vẫn sử dụng hàm mất mát entropy chéo và thuật toán huấn luyện là phương pháp hạ gradient ngẫu nhiên theo minibatch. Với mỗi epoch tốn khoảng hàng chục giây để chạy, ta sẽ vẽ đường biểu diễn giá trị mất mát huấn luyện với nhiều giá trị chi tiết hơn.

# %%
def evaluate_accuracy_gpu(net, data_iter, device=None): 
    if isinstance(net, nn.Module):
        net.eval()  
        if not device:
            device = next(iter(net.parameters())).device

    metric = d2l.Accumulator(2)

    with torch.no_grad():
        for X, y in data_iter:
            if isinstance(X, list):
                X = [x.to(device) for x in X]
            else:
                X = X.to(device)
            y = y.to(device)
            metric.add(d2l.accuracy(net(X), y), y.numel())
    return metric[0] / metric[1]

# %%
from torch import optim
from torch import nn
def train_ch6(net, train_iter, test_iter, num_epochs, lr, device):
    def init_weights(m):
        if type(m) == nn.Linear or type(m) == nn.Conv2d:
            nn.init.xavier_uniform_(m.weight) # để hạn chế vanishng exploding gradient

    net.apply(init_weights)
    print('training on', device)
    net.to(device) # chuyển model sang device trên
    optimizer = optim.Adam(net.parameters(), lr = lr) # optimizer
    criterion = nn.CrossEntropyLoss()


    animator = d2l.Animator(xlabel='epoch', xlim=[1, num_epochs],
                            legend=['train loss', 'train acc', 'test acc'])
    timer, num_batches = d2l.Timer(), len(train_iter)


    for epoch in range(num_epochs):

        metric = d2l.Accumulator(3)
        net.train()
        for i, (X, y) in enumerate(train_iter):
            timer.start()
            optimizer.zero_grad()
            X, y = X.to(device) , y.to(device) 
            y_hat = net(X)
            l = criterion(y_hat, y) # loss
            l.backward() # backward
            optimizer.step() # update
            with torch.no_grad():
                metric.add(l * X.shape[0], d2l.accuracy(y_hat, y), X.shape[0])
            timer.stop()
            train_l = metric[0] / metric[2]
            train_acc = metric[1] / metric[2]
            if (i + 1) % (num_batches // 5) == 0 or i == num_batches - 1:
                animator.add(epoch + (i + 1) / num_batches,
                             (train_l, train_acc, None))
        test_acc = evaluate_accuracy_gpu(net, test_iter) # evaluate model với test_iter
        animator.add(epoch + 1, (None, None, test_acc))
    print(f'loss {train_l:.3f}, train acc {train_acc:.3f}, '
          f'test acc {test_acc:.3f}')
    print(f'{metric[2] * num_epochs / timer.sum():.1f} examples/sec '
          f'on {str(device)}')

# %%
#Bắt đầu traning vói train_ch6
lr, num_epochs = 0.9, 10
train_ch6(net, train_iter, test_iter, num_epochs, lr, d2l.try_gpu())
# Out:
# training on cpu
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 3
#       1 #Bắt đầu traning vói train_ch6
#       2 lr, num_epochs = 0.9, 10
# ----> 3 train_ch6(net, train_iter, test_iter, num_epochs, lr, d2l.try_gpu())
#
# Cell In[16], line 29, in train_ch6(net, train_iter, test_iter, num_epochs, lr, device)
#      27 X, y = X.to(device) , y.to(device)
#      28 y_hat = net(X)
# ---> 29 l = criterion(y_hat, y) # loss
#      30 l.backward() # backward
#      31 optimizer.step() # update
#
# File /Users/miniconda3/envs/d2l/lib/python3.8/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File /Users/miniconda3/envs/d2l/lib/python3.8/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File /Users/miniconda3/envs/d2l/lib/python3.8/site-packages/torch/nn/modules/loss.py:618, in BCELoss.forward(self, input, target)
#     617 def forward(self, input: Tensor, target: Tensor) -> Tensor:
# --> 618     return F.binary_cross_entropy(input, target, weight=self.weight, reduction=self.reduction)
#
# File /Users/miniconda3/envs/d2l/lib/python3.8/site-packages/torch/nn/functional.py:3118, in binary_cross_entropy(input, target, weight, size_average, reduce, reduction)
#    3116     reduction_enum = _Reduction.get_enum(reduction)
#    3117 if target.size() != input.size():
# -> 3118     raise ValueError(
#    3119         "Using a target size ({}) that is different to the input size ({}) is deprecated. "
#    3120         "Please ensure they have the same size.".format(target.size(), input.size())
#    3121     )
#    3123 if weight is not None:
#    3124     new_size = _infer_size(target.size(), weight.size())
#
# ValueError: Using a target size (torch.Size([32])) that is different to the input size (torch.Size([32, 10])) is deprecated. Please ensure they have the same size.

# %% [markdown]
# ## Summary
#
# * Mạng nơ-ron tích chập (gọi tắt là ConvNet) là một mạng sử dụng các tầng tích chập.
#
# * Trong ConvNet, ta xen kẽ các phép tích chập, các hàm phi tuyến và các phép gộp.
#
# * Độ phân giải được giảm xuống trước khi tạo một đầu ra thông qua một (hoặc nhiều) tầng kết nối dày đặc.
#
# * Trong CNN truyền thống, các biểu diễn được mã hóa bởi các khối tích chập được xử lý bởi một hoặc nhiều lớp FC trước khi output.
#
# * LeNet là mạng ConvNet đầu tiên được triển khai thành công.

# %% [markdown]
# [Discussions](https://discuss.d2l.ai/t/275)
