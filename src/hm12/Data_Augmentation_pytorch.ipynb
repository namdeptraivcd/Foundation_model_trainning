# %% [markdown]
# \# Training neural network: Data augmentation
#
# Tiếp nối bài thực hành trên lớp, bài tập về nhà này vẫn sử dụng MNIST là tập dữ liệu thử nghiệm. Mục tiêu là cải thiện hiệu suất của mô hình bằng các kỹ thuật Augmentation nhằm tăng cường số lượng dữ liệu

# %%
import warnings
warnings.filterwarnings('ignore')
import os
import numpy as np
import matplotlib.pyplot as plt
import cv2
from keras.datasets import mnist
import torch
from torch import nn
import torch.nn.functional as F
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

# %load_ext tensorboard
# !rm -rf './graph/dropout/dropout=0.5,relu/'
# Out:
# 2025-10-24 08:57:38.156446: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1761296258.414687      78 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1761296258.482981      78 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()
print('Training image: ', x_train.shape)
print('Testing image: ', x_test.shape)
print('Training label: ', y_train.shape)
print('Testing label: ', y_test.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Training image:  (60000, 28, 28)
# Testing image:  (10000, 28, 28)
# Training label:  (60000,)
# Testing label:  (10000,)

# %%
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

# %%
class SimpleModel(nn.Module):
    def __init__(self, dropout_rate):
        super(SimpleModel, self).__init__()
        self.dense_1 = nn.Linear(28*28, 128)
        self.dropout = nn.Dropout(dropout_rate)
        self.dense_2 = nn.Linear(128, 10)
        self.relu = nn.ReLU()
    
    def forward(self, x):
        x = x.view(x.size(0), -1)
        x = self.dense_1(x)
        x = self.relu(x)
        x = self.dropout(x)
        output = F.log_softmax(self.dense_2(x))
        
        return output

# %% [markdown]
# # Check model parameter

# %%
simple_model = SimpleModel(dropout_rate = 0.5).cuda()
for param in simple_model.parameters():
    if param.requires_grad:
        print('param autograd')
        break

input = torch.rand(1, 28, 28).cuda()
output = simple_model(input)  # type: torch.Tensor

model_parameters = filter(lambda p: p.requires_grad, simple_model.parameters())
params = sum([np.prod(p.size()) for p in model_parameters])
print('Number of parameter:', params)
# Out:
# param autograd
# Number of parameter: 101770

# %% [markdown]
# ## Tăng thêm dữ liệu (data augmentation) với thư viện imgaug
#
# Trong phần thực hành này, chúng ta sẽ làm quen với các phương pháp tăng dữ liệu cho bài toán xử lý ảnh, các phương pháp này hoàn toàn có thể lập trình sử dụng thư viện numpy (vì bản chất của phương pháp là ta thao tác trên ma trận biểu diễn ảnh). Tuy nhiên, để việc lập trình được nhanh chóng, chúng ta sẽ làm quen với một thư viện rất mạnh mẽ, giúp ta nhanh chóng cài đặt nhiều phương pháp tăng dữ liệu hiệu quả khác nhau: thư viện imgaug
#
# Để cài đặt imgaug, ta sử dụng lệnh:
#
# pip install imgaug
#
# pip install scikit-image --upgrade

# %%
# Cài đặt thư viện

######################
### YOUR CODE HERE ###
######################
# !pip install imgaug
# !pip install scikit-image --upgrade
# Out:
# Collecting imgaug
#   Downloading imgaug-0.4.0-py2.py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from imgaug) (1.17.0)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.11/dist-packages (from imgaug) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from imgaug) (1.15.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from imgaug) (11.2.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from imgaug) (3.7.2)
# Requirement already satisfied: scikit-image>=0.14.2 in /usr/local/lib/python3.11/dist-packages (from imgaug) (0.25.2)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (from imgaug) (4.11.0.86)
# Requirement already satisfied: imageio in /usr/local/lib/python3.11/dist-packages (from imgaug) (2.37.0)
# Requirement already satisfied: Shapely in /usr/local/lib/python3.11/dist-packages (from imgaug) (2.1.1)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.15->imgaug) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.15->imgaug) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.15->imgaug) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.15->imgaug) (2025.2.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.15->imgaug) (2022.2.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.15->imgaug) (2.4.1)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.11/dist-packages (from scikit-image>=0.14.2->imgaug) (3.5)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.11/dist-packages (from scikit-image>=0.14.2->imgaug) (2025.6.11)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.11/dist-packages (from scikit-image>=0.14.2->imgaug) (25.0)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.11/dist-packages (from scikit-image>=0.14.2->imgaug) (0.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->imgaug) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->imgaug) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->imgaug) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->imgaug) (1.4.8)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->imgaug) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->imgaug) (2.9.0.post0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.15->imgaug) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.15->imgaug) (2022.2.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.15->imgaug) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.15->imgaug) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.15->imgaug) (2024.2.0)
# Downloading imgaug-0.4.0-py2.py3-none-any.whl (948 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 948.0/948.0 kB 26.3 MB/s eta 0:00:0000:01
# Installing collected packages: imgaug
# Successfully installed imgaug-0.4.0
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.11/dist-packages (0.25.2)
# Requirement already satisfied: numpy>=1.24 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (1.26.4)
# Requirement already satisfied: scipy>=1.11.4 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (1.15.3)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (3.5)
# Requirement already satisfied: pillow>=10.1 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (11.2.1)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (2025.6.11)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (25.0)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (0.4)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.24->scikit-image) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.24->scikit-image) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.24->scikit-image) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.24->scikit-image) (2025.2.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.24->scikit-image) (2022.2.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.24->scikit-image) (2.4.1)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.24->scikit-image) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.24->scikit-image) (2022.2.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.24->scikit-image) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.24->scikit-image) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.24->scikit-image) (2024.2.0)

# %%
from imgaug import augmenters as iaa

# %% [markdown]
# Để tìm hiểu lần lượt các phương pháp, thử áp dụng trên ảnh cat.jpg trong thư mục bài thực hành:

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("borhanitrash/cat-dataset")

print("Path to dataset files:", path)
# Out:
# Mounting files to /kaggle/input/cat-dataset...
# Path to dataset files: /kaggle/input/cat-dataset

# %%
import os
import cv2
import matplotlib.pyplot as plt
# path là thư mục gốc
print(os.listdir(path))  # ['cats']

# Đường dẫn đến thư mục chứa ảnh
cat_folder = os.path.join(path, 'cats')
print(os.listdir(cat_folder))  # Xem các file ảnh trong thư mục cats

# Đường dẫn đến thư mục chứa ảnh thực tế
data_folder = os.path.join(cat_folder, 'Data')
print(os.listdir(data_folder))  # Xem các file ảnh trong thư mục Data

# Lấy file ảnh đầu tiên (chỉ lấy 1 file, không lấy list)
image_file = os.path.join(data_folder, os.listdir(data_folder)[5])
print(image_file)



image = cv2.imread(image_file)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()
# Out:
# ['cats']
# ['README.txt', 'LICENSE.txt', 'Data']
# ['cat_26441.png', 'cat_20387.png', 'cat_9146.png', 'cat_8010.png', 'cat_13753.png', 'cat_5033.png', 'cat_20627.png', 'cat_12536.png', 'cat_27627.png', 'cat_23805.png', 'cat_28964.png', 'cat_17414.png', 'cat_20652.png', 'cat_17186.png', 'cat_17910.png', 'cat_4738.png', 'cat_1639.png', 'cat_9752.png', 'cat_15946.png', 'cat_21294.png', 'cat_5491.png', 'cat_20858.png', 'cat_25807.png', 'cat_15599.png', 'cat_8925.png', 'cat_6282.png', 'cat_7759.png', 'cat_24408.png', 'cat_12423.png', 'cat_18426.png', 'cat_25546.png', 'cat_24007.png', 'cat_4620.png', 'cat_2861.png', 'cat_23051.png', 'cat_15903.png', 'cat_3832.png', 'cat_6693.png', 'cat_15528.png', 'cat_370.png', 'cat_27208.png', 'cat_13157.png', 'cat_8435.png', 'cat_11948.png', 'cat_21196.png', 'cat_19704.png', 'cat_26839.png', 'cat_9418.png', 'cat_1667.png', 'cat_11782.png', 'cat_28607.png', 'cat_19359.png', 'cat_5613.png', 'cat_14522.png', 'cat_15352.png', 'cat_5560.png', 'cat_23398.png', 'cat_28388.png', 'cat_22165.png', 'cat_3143.png', 'cat_26043.png', 'cat_27558.png', 'cat_25477.png', 'cat_23437.png', 'cat_13655.png', 'cat_27801.png', 'cat_3848.png', 'cat_23526.png', 'cat_6067.png', 'cat_23385.png', 'cat_21434.png', 'cat_27976.png', 'cat_29631.png', 'cat_19455.png', 'cat_24154.png', 'cat_14452.png', 'cat_4338.png', 'cat_5876.png', 'cat_26115.png', 'cat_21561.png', 'cat_21081.png', 'cat_12037.png', 'cat_27367.png', 'cat_9258.png', 'cat_4708.png', 'cat_27392.png', 'cat_10154.png', 'cat_1619.png', 'cat_9573.png', 'cat_27226.png', 'cat_7501.png', 'cat_7265.png', 'cat_9088.png', 'cat_17564.png', 'cat_23863.png', 'cat_14703.png', 'cat_24102.png', 'cat_6798.png', 'cat_4059.png', 'cat_2235.png', 'cat_874.png', 'cat_26419.png', 'cat_1195.png', 'cat_22428.png', 'cat_9181.png', 'cat_20015.png', 'cat_22032.png', 'cat_17524.png', 'cat_14096.png', 'cat_20581.png', 'cat_17377.png', 'cat_9071.png', 'cat_22992.png', 'cat_4079.png', 'cat_16747.png', 'cat_27922.png', 'cat_2410.png', 'cat_24547.png', 'cat_26285.png', 'cat_28105.png', 'cat_27957.png', 'cat_27981.png', 'cat_25011.png', 'cat_17203.png', 'cat_8771.png', 'cat_17683.png', 'cat_8159.png', 'cat_3554.png', 'cat_9105.png', 'cat_14863.png', 'cat_17175.png', 'cat_9277.png', 'cat_15762.png', 'cat_51.png', 'cat_6750.png', 'cat_13470.png', 'cat_27730.png', 'cat_201.png', 'cat_22056.png', 'cat_22842.png', 'cat_26832.png', 'cat_23778.png', 'cat_27087.png', 'cat_18585.png', 'cat_6536.png', 'cat_19909.png', 'cat_29434.png', 'cat_21768.png', 'cat_4744.png', 'cat_6382.png', 'cat_23428.png', 'cat_6350.png', 'cat_7227.png', 'cat_15487.png', 'cat_25100.png', 'cat_13406.png', 'cat_25624.png', 'cat_21574.png', 'cat_14013.png', 'cat_14194.png', 'cat_24831.png', 'cat_14921.png', 'cat_29294.png', 'cat_20919.png', 'cat_2488.png', 'cat_8512.png', 'cat_8308.png', 'cat_19083.png', 'cat_13256.png', 'cat_18689.png', 'cat_4453.png', 'cat_10598.png', 'cat_8903.png', 'cat_318.png', 'cat_10795.png', 'cat_26779.png', 'cat_9839.png', 'cat_13430.png', 'cat_6006.png', 'cat_24660.png', 'cat_26332.png', 'cat_25364.png', 'cat_13086.png', 'cat_2379.png', 'cat_24705.png', 'cat_19880.png', 'cat_21860.png', 'cat_5551.png', 'cat_25126.png', 'cat_18626.png', 'cat_22291.png', 'cat_1201.png', 'cat_29468.png', 'cat_5894.png', 'cat_353.png', 'cat_20522.png', 'cat_14810.png', 'cat_2150.png', 'cat_477.png', 'cat_17089.png', 'cat_18862.png', 'cat_19640.png', 'cat_12032.png', 'cat_3393.png', 'cat_23928.png', 'cat_1159.png', 'cat_10129.png', 'cat_11898.png', 'cat_13521.png', 'cat_555.png', 'cat_1335.png', 'cat_4204.png', 'cat_28103.png', 'cat_2667.png', 'cat_8575.png', 'cat_21565.png', 'cat_28632.png', 'cat_1751.png', 'cat_24369.png', 'cat_7564.png', 'cat_22598.png', 'cat_13285.png', 'cat_12466.png', 'cat_13045.png', 'cat_3628.png', 'cat_11431.png', 'cat_9928.png', 'cat_29840.png', 'cat_7378.png', 'cat_21145.png', 'cat_11425.png', 'cat_28702.png', 'cat_8449.png', 'cat_1805.png', 'cat_3052.png', 'cat_14959.png', 'cat_26141.png', 'cat_24320.png', 'cat_9694.png', 'cat_23529.png', 'cat_4472.png ...
# /kaggle/input/cat-dataset/cats/Data/cat_5033.png

# %% [markdown]
# ### Các phương pháp thường sử dụng
#
# Các phương pháp hay được sử dụng nhất trong các bài toán xử lý ảnh có thể tham khảo tại: https://imgaug.readthedocs.io/en/latest/source/augmenters.html

# %% [markdown]
# 1. CropAndPad: Cắt hoặc thêm các pixel vào ảnh.

# %%
# Sử dụng hàm CropAndPad với tham số percent=(-0.25, 0.25)

######################
crop_and_pad = iaa.CropAndPad(percent=(-0.25, 0.25))
######################

plt.imshow(cv2.cvtColor(crop_and_pad.augment_image(image), cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()

# %% [markdown]
# 2. Flip: Flip left-right hoặc Flip up-down một số ảnh trong tập ảnh truyền vào

# %%
# Flip left-right sử dụng hàm Fliplr với tham số 1.0

######################
flip_lr = iaa.Fliplr(1.0)
######################

plt.imshow(cv2.cvtColor(flip_lr.augment_image(image), cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()

# %%
# Flip up-down sử dụng hàm Flipud với tham số 1.0

######################
flip_ud = iaa.Flipud(0.6)
######################

plt.imshow(cv2.cvtColor(flip_ud.augment_image(image), cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# - Affine: Các phép biến đổi affine như scale, rotate, translate:

# %%
# Biến đổi affine dùng hàm Affine với các tham số scale=(0.5, 1.5), rotate=(-15,15), translate_percent=(-0.2, 0.2)

######################
affine = iaa.Affine(scale=(0.5, 1.5), rotate=(-15, 15), translate_percent=(-0.2, 0.2))
######################

plt.imshow(cv2.cvtColor(affine.augment_image(image), cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# - Blur: Sử dụng các bộ lọc Gaussian hoặc Mean:

# %%
# Sử dụng hàm AverageBlur để thực hiện Mean filter với tham số k = (11,31), GaussianBlur để thực hiện Gausian Blur với Sigma = (5,15)

######################
avg_blur = iaa.AverageBlur(k=(11,31))
gauss_blur = iaa.GaussianBlur(sigma=(5.0, 15.0))
######################

plt.imshow(cv2.cvtColor(avg_blur.augment_image(image), cv2.COLOR_BGR2RGB))
plt.show()
plt.imshow(cv2.cvtColor(gauss_blur.augment_image(image), cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# - Dropout: Biến đổi ngẫu nhiên một phần ảnh thành các pixel đen

# %%
# Dropout với tham số p = (0, 0.2) 

######################
dropout = iaa.Dropout(p=(0, 0.2))
######################

plt.imshow(cv2.cvtColor(dropout.augment_image(image), cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# ### Kết hợp nhiều augmenter
#
# Trong thực tế, có nhiều chiến lược trong việc thực hiện các augmenter khác nhau, thư viện imgaug cũng hỗ trợ một số hàm để thực hiện công việc này:

# %% [markdown]
# - Sequential: Áp dụng các augmenter lần lượt theo thứ tự truyền vào:

# %%
aug = iaa.Sequential([
    iaa.Affine(translate_px={"x":(-40, 40)}),
    iaa.AdditiveGaussianNoise(scale=0.1*255)
])

plt.imshow(cv2.cvtColor(aug.augment_image(image), cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# - SomeOf: Áp dụng ngẫu nhiên một vài augmenter trong list các augmenter:

# %%
import numpy as np
np.bool = bool  # Fix cho các thư viện cũ dùng np.bool
aug = iaa.SomeOf(2, [
    iaa.Affine(rotate=45),
    iaa.AdditiveGaussianNoise(scale=0.2*255),
    iaa.Add(50, per_channel=True),
    iaa.Sharpen(alpha=0.5)
])

plt.imshow(cv2.cvtColor(aug.augment_image(image), cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# - Sometimes: Áp dụng augmenter với xác suất p:

# %%
aug = iaa.Sometimes(0.5, iaa.GaussianBlur(sigma=20.0))

plt.imshow(cv2.cvtColor(aug.augment_image(image), cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# ### Kết hợp cùng thư viện Keras
#
# Bây giờ chúng ta sẽ sử dụng các augmenter đã viết để thực hiện augment image trong quá trình huấn luyện mạng với thư viện Keras.

# %% [markdown]
# - Bước 1: Khởi tạo Augmenter:

# %%
 # Sử dụng hàm Dropout với tham số p=(0, 0.002)

######################
our_aug = iaa.Dropout(p=(0, 0.002))
######################

# %% [markdown]
# - Bước 2: Xây dựng generator:

# %%
class Generator(Dataset):
    def __init__(self, images, labels):
        self.images = images
        self.labels = labels

    def __len__(self):
        return self.images.shape[0]

    def __getitem__(self, idx):
        return self.images[idx], self.labels[idx]

# %%
training_data = Generator(x_train, y_train)
train_dataloader = DataLoader(training_data, batch_size=32, shuffle=True)

# %%
test_data = Generator(x_test, y_test)
test_dataloader = DataLoader(test_data, batch_size=32, shuffle=True)

# %% [markdown]
# Quan sát thử kết quả của generator bên trên:

# %%
for (batch_idx, target_tuple) in enumerate(train_dataloader):
    print(target_tuple[0].shape)
    for i in range(32):
        plt.subplot(4, 8, i + 1), plt.imshow(target_tuple[0][i], cmap='gray')
    plt.show()
    break
# Out:
# torch.Size([32, 28, 28])

# %% [markdown]
# - Bước 3: Train model với fit_generator:

# %%
use_cuda = torch.cuda.is_available()  #GPU cuda
best_loss = float('inf')

model = SimpleModel(dropout_rate = 0.5)

optimizer = torch.optim.Adadelta(model.parameters())

if use_cuda:
    model = torch.nn.parallel.DataParallel(model.cuda())   # , device_ids=[0, 1, 2, 3]
    torch.backends.cudnn.benchmark = True

# %%
def train(epoch):
    print('\n ############################# Train phase, Epoch: {} #############################'.format(epoch))
    model.train()
    train_loss = 0

    print('\nLearning rate at this epoch is: ', optimizer.param_groups[0]['lr'], '\n')

    for (batch_idx, target_tuple) in enumerate(train_dataloader):
        if use_cuda:
            target_tuple = [target_tensor.cuda(non_blocking=True) for target_tensor in target_tuple]

        images, labels = target_tuple
        # Convert label to long type pytorch
        labels = torch.tensor(labels,dtype=torch.long)

        optimizer.zero_grad()  # zero the gradient buff
        output_tuple = model(images)

        loss = F.nll_loss(output_tuple, labels).cuda()

        loss.backward()  # retain_graph=True
        optimizer.step()

        train_loss += loss.item()  # loss　　　
        print('########################### Epoch:', epoch, ', --  batch:',  batch_idx, '/', len(train_dataloader), ',   ',
              'Train loss: %.3f, accumulated average loss: %.3f ##############################' % (loss.item(), train_loss / (batch_idx + 1)))

    global best_loss
    train_loss /= len(train_dataloader)
    if train_loss < best_loss:
      noti = 'best_'
      best_loss = train_loss
    else:
      noti = ''
    print('saving...')
    state = {
      'weights': model.module.state_dict(),
      'optimizer_weight': optimizer.state_dict(),
      'train_loss': train_loss,
      'epoch': epoch,
    }
    os.makedirs('checkpoints', exist_ok=True)
    torch.save(state, 'checkpoints/model_' + noti + str(epoch) + '_epoch.pth')

# %%
def test(epoch):
    print('\n ############################# Test phase, Epoch: {} #############################'.format(epoch))
    model.eval()
    with torch.no_grad():
        test_loss = 0

        for (batch_idx, target_tuple) in enumerate(test_dataloader):
            if use_cuda:
                target_tuple = [target_tensor.cuda(non_blocking=True) for target_tensor in target_tuple]

            images, labels = target_tuple
            # Convert label to long type pytorch
            labels = torch.tensor(labels,dtype=torch.long)
            output_tuple = model(images)

            loss = F.nll_loss(output_tuple, labels).cuda()

            test_loss += loss.item()  # loss　　　
            print('########################### Epoch:', epoch, ', --  batch:',  batch_idx, '/', len(test_dataloader), ',   ',
                  'Test loss: %.3f, accumulated average loss: %.3f ##############################' % (loss.item(), test_loss / (batch_idx + 1)))

# %%
no_epoch = 5
for epoch in range(no_epoch):
    train(epoch)
    test(epoch)
# Out:
#  ############################# Train phase, Epoch: 0 #############################
#
# Learning rate at this epoch is:  1.0
#
# ########################### Epoch: 0 , --  batch: 0 / 1875 ,    Train loss: 2.305, accumulated average loss: 2.305 ##############################
# ########################### Epoch: 0 , --  batch: 1 / 1875 ,    Train loss: 2.264, accumulated average loss: 2.285 ##############################
# ########################### Epoch: 0 , --  batch: 2 / 1875 ,    Train loss: 2.207, accumulated average loss: 2.259 ##############################
# ########################### Epoch: 0 , --  batch: 3 / 1875 ,    Train loss: 2.128, accumulated average loss: 2.226 ##############################
# ########################### Epoch: 0 , --  batch: 4 / 1875 ,    Train loss: 2.162, accumulated average loss: 2.213 ##############################
# ########################### Epoch: 0 , --  batch: 5 / 1875 ,    Train loss: 2.106, accumulated average loss: 2.195 ##############################
# ########################### Epoch: 0 , --  batch: 6 / 1875 ,    Train loss: 1.953, accumulated average loss: 2.161 ##############################
# ########################### Epoch: 0 , --  batch: 7 / 1875 ,    Train loss: 2.116, accumulated average loss: 2.155 ##############################
# ########################### Epoch: 0 , --  batch: 8 / 1875 ,    Train loss: 1.931, accumulated average loss: 2.130 ##############################
# ########################### Epoch: 0 , --  batch: 9 / 1875 ,    Train loss: 1.827, accumulated average loss: 2.100 ##############################
# ########################### Epoch: 0 , --  batch: 10 / 1875 ,    Train loss: 1.610, accumulated average loss: 2.055 ##############################
# ########################### Epoch: 0 , --  batch: 11 / 1875 ,    Train loss: 1.723, accumulated average loss: 2.028 ##############################
# ########################### Epoch: 0 , --  batch: 12 / 1875 ,    Train loss: 1.611, accumulated average loss: 1.996 ##############################
# ########################### Epoch: 0 , --  batch: 13 / 1875 ,    Train loss: 1.450, accumulated average loss: 1.957 ##############################
# ########################### Epoch: 0 , --  batch: 14 / 1875 ,    Train loss: 1.421, accumulated average loss: 1.921 ##############################
# ########################### Epoch: 0 , --  batch: 15 / 1875 ,    Train loss: 1.347, accumulated average loss: 1.885 ##############################
# ########################### Epoch: 0 , --  batch: 16 / 1875 ,    Train loss: 1.471, accumulated average loss: 1.861 ##############################
# ########################### Epoch: 0 , --  batch: 17 / 1875 ,    Train loss: 1.431, accumulated average loss: 1.837 ##############################
# ########################### Epoch: 0 , --  batch: 18 / 1875 ,    Train loss: 1.518, accumulated average loss: 1.820 ##############################
# ########################### Epoch: 0 , --  batch: 19 / 1875 ,    Train loss: 1.293, accumulated average loss: 1.794 ##############################
# ########################### Epoch: 0 , --  batch: 20 / 1875 ,    Train loss: 1.387, accumulated average loss: 1.774 ##############################
# ########################### Epoch: 0 , --  batch: 21 / 1875 ,    Train loss: 1.351, accumulated average loss: 1.755 ##############################
# ########################### Epoch: 0 , --  batch: 22 / 1875 ,    Train loss: 1.086, accumulated average loss: 1.726 ##############################
# ########################### Epoch: 0 , --  batch: 23 / 1875 ,    Train loss: 0.958, accumulated average loss: 1.694 ##############################
# ########################### Epoch: 0 , --  batch: 24 / 1875 ,    Train loss: 1.404, accumulated average loss: 1.682 ##############################
# ########################### Epoch: 0 , --  batch: 25 / 1875 ,    Train loss: 1.025, accumulated average loss: 1.657 ##############################
# ########################### Epoch: 0 , --  batch: 26 / 1875 ,    Train loss: 1.151, accumulated average loss: 1.638 ##############################
# ########################### Epoch: 0 , --  batch: 27 / 1875 ,    Train loss: 1.240, accumulated average loss: 1.624 ##############################
# ########################### Epoch: 0 , --  batch: 28 / 1875 ,    Train loss: 1.005, accumulated average loss: 1.603 ##############################
# ########################### Epoch: 0 , --  batch: 29 / 1875 ,    Train loss: 0.979, accumulated average loss: 1.582 ##############################
# ########################### Epoch: 0 , --  batch: 30 / 1875 ,    Train loss: 1.003, accumulated average loss: 1.563 ##############################
# ########################### Epoch: 0 , --  batch: 31 / 1875 ,    Train loss: 0.644, accumulated average loss: 1.535 ##############################
# ########################### Epoch: 0 , --  batch: 32 / 1875 ,    Train loss: 1.112, accumulated average loss: 1.522 ##############################
# ########################### Epoch: 0 , --  batch: 33 / 1875 ,    Train loss: 0.984, accumulated average loss: 1.506 ##############################
# ########################### Epoch: 0 , --  batch: 34 / 1875 ,    Train loss: 1.072, accumulated average loss: 1.494 ##############################
# ########################### Epoch: 0 , --  batch: 35 / 1875 ,    Train loss: 0.911, accumulated average loss: 1.477 ##############################
# ########################### Epoch: 0 , --  batch: 36 / 1875 ,    Train loss: 0.794, accumulated average loss: 1.459 ##############################
# ########################### Epoch: 0 , --  batch: 37 / 1875 ,    Train loss: 0.776, accumulated average loss: 1.441 ##############################
# ########################### Epoch: 0 , --  batch: 38 / 1875 ,    Train loss: 0.823, accumulated average loss: 1.425 ##############################
# ########################### Epoch: 0 , --  batch: 39 / 1875 ,    Train loss: 0.824, accumulated average loss: 1.410 ##############################
# ########################### Epoch: 0 , --  batch: 40 / 1875 ,    Train loss: 0.718, accumulated average loss: 1.393 ##############################
# ########################### Epoch: 0 , --  batch: 41 / 1875 ,    Train loss: 0.992, accumulated average loss: 1.384 ##############################
# ########################### Epoch: 0 , --  batch: 42 / 1875 ,    Train loss: 0.717, accumulated average loss: 1.368 ##############################
# ########################### Epoch: 0 , --  batch: 43 / 1875 ,    Train loss: 1.038, accumulated average loss: 1.361 ##############################
# ########################### Epoch: 0 , --  batch: 44 / 1875 ,    Train loss: 0.942, accumulated average loss: 1.351 ##############################
# ########################### Epoch: 0 , --  batch: 45 / 1875 ,    Train loss: 0.746, accumulated average loss: 1.338 ##############################
# ########################### Epoch: 0 , --  batch: 46 / 1875 ,    Train loss: 0.785, accumulated average loss: 1.326 ##############################
# ########################### Epoch: 0 , --  batch: 47 / 1875 ,    Train loss: 0.753, accumulated average loss: 1.314 ##############################
# ########################### Epoch: 0 , --  batch: 48 / 1875 ,    Train loss: 0.928, accumulated average loss: 1.307 ##############################
# ########################### Epoch: 0 , --  batch: 49 / 1875 ,    Train loss: 0.731, accumulated average loss: 1.295 ##############################
# ########################### Epoch: 0 , --  batch: 50 / 1875 ,    Train loss: 0.750, accumulated average loss: 1.284 ##############################
# ########################### Epoch: 0 , --  batch: 51 / 1875 ,    Train loss: 0.590, accumulated average loss: 1.271 ##############################
# ########################### Epoch: 0 , --  batch: 52 / 1875 ,    Train loss: 0.614, accumulated average loss: 1.259 ##############################
# ########################### Epoch: 0 , --  batch: 53 / 1875 ,    Train loss: 0.873, accumulated average loss: 1.251 ##############################
# ########################### Epoch: 0 , --  batch: 54 / 1875 ,    Train loss: 1.042, accumulated average loss: 1.248 ##############################
# ########################### Epoch: 0 , --  batch: 55 / 1875 ,    Train loss: 0.558, accumulated average loss: 1.235 ##############################
# ########################### Epoch: 0 , --  batch: 56 / 1875 ,    Train loss: 0.689, accumulated average loss: 1.226 ##############################
# ########################### Epoch: 0 , --  batch: 57 / 1875 ,    Train loss: 0.755, accumulated average loss: 1.218 ##############################
# ########################### Epoch: 0 , --  batch: 58 / 1875 ,    Train loss: 0.677, accumulated average loss: 1.208 ##############################
# ########################### Epoch: 0 , --  batch: 59 / 1875 ,    Train loss: 0.733, accumulated average loss: 1.201 ##############################
# ########################### Epoch: 0 , --  batch: 60 / 1875 ,    Train loss: 0.682, accumulated average loss: 1.192 ##############################
# ########################### Epoch: 0 , --  batch: 61 / 1875 ,    Train loss: 0.712, accumulated average loss: 1.184 ##############################
# ########################### Epoch: 0 , --  batch: 62 / 1875 ,    Train loss: 1.018, accumulated average loss: 1.182 ##############################
# ########################### Epoch: 0 , --  batch: 63 / 1875 ,    Train loss: 0.761, accumulated average loss: 1.175 ##############################
# ########################### Epoch: 0 , --  batch: 64 / 1875 ,    Train loss: 0.750, accumulated average loss: 1.169 ##############################
# ########################### Epoch: 0 , --  batch: 65 / 1875 ,    Train loss: 0.908, accumulated average loss: 1.165 ##############################
# ########################### Epoch: 0 , --  batch: 66 / 1875 ,    Train loss: 0.793, accumulated average loss: 1.159 ##############################
# ########################### Epoch: 0 , --  batch: 67 / 1875 ,    Train loss: 0.732, accumulated average loss: 1.153 ##############################
# ########################### Epoch: 0 , --  batch: 68 / 1875 ,    Train loss: 0.595, accumulated average loss: 1.145 ##############################
# ########################### Epoch: 0 , --  batch: 69 / 1875 ,    Train loss: 0.652, accumulated average loss: 1.138 ##############################
# ########################### Epoch: 0 , --  batch: 70 / 1875 ,    Train loss: 0.771, accumulated average loss: 1.133 ##############################
# ########################### Epoch: 0 , --  batch: 71 / 1875 ,    Train loss: 0.496, accumulated average loss: 1.124 ##############################
# ########################### Epoch: 0 , --  batch: 72 / 1875 ,    Train loss: 0.616, accumulated average loss: 1.117 ##############################
# ########################### Epoch: 0 , --  batch: 73 / 1875 ,    Train loss: 0.660, accumulated average loss: 1.111 ##############################
# ########################### Epoch: 0 , --  batch: 74 / 1875 ,    Train loss: 0.544, accumulated average loss: 1.103 ##############################
# ########################### Epoch: 0 , --  batch: 75 / 1875 ,    Train loss: 0.581, accumulated average loss: 1.096 ##############################
# ########################### Epoch: 0 , --  batch: 76 / 1875 ,    Train loss: 1.059, accumulated average loss: 1.096 ##############################
# ########################### Epoch: 0 , --  batch: 77 / 1875 ,    Train loss: 0.404, accumulated average loss: 1.087 ##############################
# ########################### Epoch: 0 , --  batch: 78 / 1875 ,    Train loss: 0.540, accumulated average loss: 1.080 ##############################
# ########################### Epoch: 0 , --  batch: 79 / 1875 ,    Train loss: 0.768, accumulated average loss: 1.076 ##############################
# ########################### Epoch: 0 , --  batch: 80 / 1875 ,    Train loss: 0.784, accumulated average loss: 1.072 ##############################
# ########################### Epoch: 0 , --  batch: 81 / 1875 ,    Train loss: 0.990, accumulated average loss: 1.071 ##############################
# ########################### Epoch: 0 , --  batch: 82 / 1875 ,    Train loss: 0.504, accumulated average loss: 1.065 ##############################
# ########################### Epoch: 0 , --  batch: 83 / 1875 ,    Train loss: 0.415, accumulated average loss: 1.057 ##############################
# ########################### Epoch: 0 , --  batch: 84 / 1875 ,    Train loss: 0.525, accumulated average loss: 1.051 ##############################
# ########################### Epoch: 0 , --  batch: 85 / 1875 ,    Train loss: 0.432, accumulated average loss: 1.043 ##############################
# ########################### Epoch: 0 , --  batch: 86 / 1875 ,    Train loss: 0.591, accumulated average loss: 1.038 ##############################
# ########################### Epoch: 0 , --  batch: 87 / 1875 ,    Train loss: 0.498, accumulated average loss: 1.032 ##############################
# ########################### Epoch: 0 , --  batch: 88 / 1875 ,    Train loss: 0.830, accumulated average loss: 1.030 ##############################
# ########################### Epoch: 0 , --  batch: 89 / 1875 ,    Train loss: 0.825, accumulated average loss: 1.027 ##############################
# ########################### Epoch: 0 , --  batch: 90 / 1875 ,    Train loss: 0.474, accumulated average loss: 1.021 ##############################
# ########################### Epoch: 0 , --  batch: 91 / 1875 ,    Train loss: 0.352, accumulated average loss: 1.014 ##############################
# ########################### Epoch: 0 , --  batch: 92 / 1875 ,    Train loss: 0.419, accumulated average loss: 1.008 ##############################
# ########################### Epoch: 0 , --  batch: 93 / 1875 ,    Train loss: 0.633, accumulated average loss: 1.004 ##############################
# ########################### Epoch: 0 , --  batch: 94 / 1875 ,    Train loss: 0.375, accumulated average loss: 0.997 ##############################
# ########################### Epoch: 0 , --  batch: 95 / 1875 ,    Train loss: 0.693, accumulated average loss: 0.994 ##############################
# ########################### Epoch: 0 , --  batch: 96 / 1875 ,    Train loss: 0.553, accumulated average loss: 0.989 ##############################
# ########################### Epoch: 0 , --  batch: 97 / 1875 ,    Train loss: 0.368, accumulated average loss: 0.983 ##############################
# ########################### Epoch: 0 , --  batch: 98 / 1875 ,    Train loss: 0.726, accumulated average loss: 0.980 ##############################
# ########################### Epoch: 0 , --  batch: 99 / 1875 ,    Train loss: 0.659, accumulated average loss: 0.977 ##############################
# ########################### Epoch: 0 , --  batch: 100 / 1875 ,    Train loss: 0.626, accumulated average loss: 0.974 ##############################
# ########################### Epoch: 0 , --  batch: 101 / 1875 ,    Train loss: 0.641, accumulated average loss: 0.971 ##############################
# ########################### Epoch: 0 , --  batch: 102 / 1875 ,    Train loss: 0.667, accumulated average loss: 0.968 ##############################
# ########################### Epoch: 0 , --  batch: 103 / 1875 ,    Train loss: 0.453, accumulated average loss: 0.963 ##############################
# ########################### Epoch: 0 , --  batch: 104 / 1875 ,    Train loss: 0.479, accumulated average loss: 0.958 ##############################
# ########################### Epoch: 0 , --  batch: 105 / 1875 ,    Train loss: 0.633, accumulated average loss: 0.955 ##############################
# ########################### Epoch: 0 , --  batch: 106 / 1875 ,    Train loss: 0.482, accumulated average loss: 0.951 ##############################
# ########################### Epoch: 0 , --  batch: 107 / 1875 ,    Train loss: 0.485, accumulated average loss: 0.946 ##############################
# ########################### Epoch: 0 , --  batch: 108 / 1875 ,    Train loss: 0.417, accumulated average loss: 0.941 ##############################
# ########################### Epoch: 0 , --  batch: 109 / 1875 ,    Train loss: 0.746, accumulated average loss: 0.940 ##############################
# ########################### Epoch: 0 , --  batch: 110 / 1875 ,    Train loss: 0.577, accumulated average loss: 0.936 ##############################
# ########################### Epoch: 0 , --  batch: 111 / 1875 ,    Train loss: 0.371, accumulated average loss: 0.931 ##############################
# ########################### Epoch: 0 , --  batch: 112 / 1875 ,    Train loss: 0.712, accumulated average loss: 0.929 ##############################
# ########################### Epoch: 0 , --  batch: 113 / 1875 ,    Train loss: 0.655, accumulated average loss: 0.927 ##############################
# ########################### Epoch: 0 , --  batch: 114 / 1875 ,    Train loss: 0.510, accumulated average loss: 0.923 ##############################
# ########################### Epoch: 0 , --  batch: 115 / 1875 ,    Train loss: 0.447, accumulated average loss: 0.919 ##############################
# ########################### Epoch: 0 , --  batch: 116 / 1875 ,    Train loss: 0.386, accumulated average loss: 0.915 ##############################
# ########################### Epoch: 0 , --  batch: 117 / 1875 ,    Train loss: 0.342, accumulated average loss: 0.910 ##############################
# ########################### Epoch: 0 , --  batch: 118 / 1875 ,    Train loss: 0.708, accumulated average loss: 0.908 ##############################
# ########################### Epoch: 0 , --  batch: 119 / 1875 ,    Train loss: 0.534, accumulated average loss: 0.905 ##############################
# ########################### Epoch: 0 , --  batch: 120 / 1875 ,    Train loss: 0.443, accumulated average loss: 0.901 ##############################
# ########################### Epoch: 0 , --  batch: 121 / 1875 ,    Train loss: 0.508, accumulated average loss: 0.898 ##############################
# ########################### Epoch: 0 , --  batch: 122 / 1875 ,    Train loss: 0.483, accumulated average loss: 0.895 ##############################
# ########################### Epoch: 0 , --  batch: 123 / 1875 ,    Train loss: 0.350, accumulated average loss: 0.890 ##############################
# ########################### Epoch: 0 , --  batch: 124 / 1875 ,    Train loss: 0.586, accumulated average loss: 0.888 ##############################
# ########################### Epoch: 0 , --  batch: 125 / 1875 ,    Train loss: 0.796, accumulated average loss: 0.887 ##############################
# ########################### Epoch: 0 , --  batch: 126 / 1875 ,    Train loss: 0.507, accumulated average loss: 0.884 ##############################
# ########################### Epoch: 0 , --  batch: 127 / 1875 ,    Train loss: 0.645, accumulated average loss: 0.882 ##############################
# ########################### Epoch: 0 , --  batch: 128 / 1875 ,    Train loss: 1.013, accumulated average loss: 0.883 ##############################
# ########################### Epoch: 0 , --  batch: 129 / 1875 ,    Train loss: 0.638, accumulated average loss: 0.881 ##############################
# ########################### Epoch: 0 , --  batch: 130 / 1875 ,    Train loss: 0.480, accumulated average loss: 0.878 ##############################
# ########################### Epoch: 0 , --  batch: 131 / 1875 ,    Train loss: 0.307, accumulated average loss: 0.874 ##############################
# ########################### Epoch: 0 , --  batch: 132 / 1875 ,    Train loss: 0.467, accumulated average loss: 0.871 ##############################
# ########################### Epoch: 0 , --  batch: 133 / 1875 ,    Train loss: 0.556, accumulated average loss: 0.868 ##############################
# ########################### Epoch: 0 , --  batch: 134 / 1875 ,    Train loss: 0.363, accumulated average loss: 0.865 ##############################
# ########################### Epoch: 0 , --  batch: 135 / 1875 ,    Train loss: 0.786, accumulated average loss: 0.864 ##############################
# ########################### Epoch: 0 , --  batch: 136 / 1875 ,    Train loss: 0.324, accumulated average loss: 0.860 ##############################
# ########################### Epoch: 0 , --  batch: 137 / 1875 ,    Train loss: 0.344, accumulated average loss: 0.856 ##############################
# ########################### Epoch: 0 , --  batch: 138 / 1875 ,    Train loss: 0.869, accumulated average loss: 0.857 ##############################
# ########################### Epoch: 0 , --  batch: 139 / 1875 ,    Train loss: 0.346, accumulated average loss: 0.853 ##############################
# ########################### Epoch: 0 , --  batch: 140 / 1875 ,    Train loss: 0.712, accumulated average loss: 0.852 ##############################
# ########################### Epoch: 0 , --  batch: 141 / 1875 ,    Train loss: 0.477, accumulated average loss: 0.849 ##############################
# ########################### Epoch: 0 , --  batch: 142 / 1875 ,    Train loss: 0.655, accumulated average loss: 0.848 ##############################
# ########################### Epoch: 0 , --  batch: 143 / 1875 ,    Train loss: 0.993, accumulated average loss: 0.849 ##############################
# ########################### Epoch: 0 , --  batch: 144 / 1875 ,    Train loss: 0.487, accumulated average loss: 0.846 ##############################
# ########################### Epoch: 0 , --  batch: 145 / 1875 ,    Train loss: 0.411, accumulated average loss: 0.843 ##############################
# ########################### Epoch: 0 , --  batch: 146 / 1875 ,    Train loss: 0.559, accumulated average loss: 0.842 ##############################
# ########################### Epoch: 0 , --  batch: 147 / 1875 ,    Train loss: 0.412, accumulated average loss: 0.839 ##############################
# ########################### Epoch: 0 , --  batch: 148 / 1875 ,    Train loss: 0.457, accumulated average loss: 0.836 ##############################
# ########################### Epoch: 0 , --  batch: 149 / 1875 ,    Train loss: 0.427, accumulated average loss: 0.833 ##############################
# ########################### Epoch: 0 , --  batch: 150 / 1875 ,    Train loss: 0.604, accumulated average loss: 0.832 ##############################
# ########################### Epoch: 0 , --  batch: 151 / 1875 ,    Train loss: 0.355, accumulated average loss: 0.829 ##############################
# ########################### Epoch: 0 , --  batch: 152 / 1875 ,    Train loss: 0.640, accumulated average loss: 0.827 ##############################
# ########################### Epoch: 0 , --  batch: 153 / 1875 ,    Train loss: 0.880, accumulated average loss: 0.828 ##############################
# ########################### Epoch: 0 , --  batch: 154 / 1875 ,    Train loss: 0.755, accumulated average loss: 0.827 ##############################
# ########################### Epoch: 0 , --  batch: 155 / 1875 ,    Train loss: 0.320, accumulated average loss: 0.824 ##############################
# ########################### Epoch: 0 , --  batch: 156 / 1875 ,    Train loss: 0.383, accumulated average loss: 0.821 ##############################
# ########################### Epoch: 0 , --  batch: 157 / 1875 ,    Train loss: 0.426, accumulated average loss: 0.819 ##############################
# ########################### Epoch: 0 , --  batch: 158 / 1875 ,    Train loss: 0.569, accumulated average loss: 0.817 ##############################
# ########################### Epoch: 0 , --  batch: 159 / 1875 ,    Train loss: 0.529, accumulated average loss: 0.815 ##############################
# ########################### Epoch: 0 , --  batch: 160 / 1875 ,    Train loss: 0.566, accumulated average loss: 0.814 ##############################
# ########################### Epoch: 0 , --  batch: 161 / 1875 ,    Train loss: 0.245, accumulated average loss: 0.810 ##############################
# ########################### Epoch: 0 , --  batch: 162 / 1875 ,    Train loss: 0.447, accumulated average loss: 0.808 ##############################
# ########################### Epoch: 0 , --  batch: 163 / 1875 ,    Train loss: 0.300, accumulated average loss: 0.805 ##############################
# ########################### Epoch: 0 , --  batch: 164 / 1875 ,    Train loss: 0.285, accumulated average loss: 0.802 ##############################
# ########################### Epoch: 0 , --  batch: 165 / 1875 ,    Train loss: 0.365, accumulated average loss: 0.799 ##############################
# ########################### Epoch: 0 , --  batch: 166 / 1875 ,    Train loss: 0.370, accumulated average loss: 0.797 ##############################
# ########################### Epoch: 0 , --  batch: 167 / 1875 ,    Train loss: 0.682, accumulated average loss: 0.796 ##############################
# ########################### Epoch: 0 , --  batch: 168 / 1875 ,    Train loss: 0.714, accumulated average loss: 0.795 ##############################
# ########################### Epoch: 0 , --  batch: 169 / 1875 ,    Train loss: 0.191, accumulated average loss: 0.792 ##############################
# ########################### Epoch: 0 , --  batch: 170 / 1875 ,    Train loss: 0.321, accumulated average loss: 0.789 ##############################
# ########################### Epoch: 0 , --  batch: 171 / 1875 ,    Train loss: 0.534, accumulated average loss: 0.788 ##############################
# ########################### Epoch: 0 , --  batch: 172 / 1875 ,    Train loss: 0.269, accumulated average loss: 0.785 ##############################
# ########################### Epoch: 0 , --  batch: 173 / 1875 ,    Train loss: 0.359, accumulated average loss: 0.782 ##############################
# ########################### Epoch: 0 , --  batch: 174 / 1875 ,    Train loss: 0.461, accumulated average loss: 0.780 ##############################
# ########################### Epoch: 0 , --  batch: 175 / 1875 ,    Train loss: 0.455, accumulated average loss: 0.779 ##############################
# ########################### Epoch: 0 , --  batch: 176 / 1875 ,    Train loss: 0.501, accumulated average loss: 0.777 ##############################
# ########################### Epoch: 0 , --  batch: 177 / 1875 ,    Train loss: 0.252, accumulated average loss: 0.774 ##############################
# ########################### Epoch: 0 , --  batch: 178 / 1875 ,    Train loss: 0.670, accumulated average loss: 0.773 ##############################
# ########################### Epoch: 0 , --  batch: 179 / 1875 ,    Train loss: 0.236, accumulated average loss: 0.770 ##############################
# ########################### Epoch: 0 , --  batch: 180 / 1875 ,    Train loss: 0.704, accumulated average loss: 0.770 ##############################
# ########################### Epoch: 0 , --  batch: 181 / 1875 ,    Train loss: 0.307, accumulated average loss: 0.768 ##############################
# ########################### Epoch: 0 , --  batch: 182 / 1875 ,    Train loss: 0.381, accumulated average loss: 0.765 ##############################
# ########################### Epoch: 0 , --  batch: 183 / 1875 ,    Train loss: 0.243, accumulated average loss: 0.763 ##############################
# ########################### Epoch: 0 , --  batch: 184 / 1875 ,    Train loss: 0.551, accumulated average loss: 0.761 ##############################
# ########################### Epoch: 0 , --  batch: 185 / 1875 ,    Train loss: 0.470, accumulated average loss: 0.760 ##############################
# ########################### Epoch: 0 , --  batch: 186 / 1875 ,    Train loss: 0.558, accumulated average loss: 0.759 ##############################
# ########################### Epoch: 0 , --  batch: 187 / 1875 ,    Train loss: 0.567, accumulated average loss: 0.758 ##############################
# ########################### Epoch: 0 , --  batch: 188 / 1875 ,    Train loss: 0.717, accumulated average loss: 0.758 ##############################
# ########################### Epoch: 0 , --  batch: 189 / 1875 ,    Train loss: 0.417, accumulated average loss: 0.756 ##############################
# ########################### Epoch: 0 , --  batch: 190 / 1875 ,    Train loss: 0.733, accumulated average loss: 0.756 ##############################
# ########################### Epoch: 0 , --  batch: 191 / 1875 ,    Train loss: 0.373, accumulated average loss: 0.754 ##############################
# ########################### Epoch: 0 , --  batch: 192 / 1875 ,    Train loss: 0.525, accumulated average loss: 0.752 ##############################
# ########################### Epoch: 0 , --  batch: 193 / 1875 ,    Train loss: 0.393, accumulated average loss: 0.751 ##############################
# ########################### Epoch: 0 , --  batch: 194 / 1875 ,    Train loss: 0.229, accumulated average loss: 0.748 ##############################
# ########################### Epoch: 0 , --  batch: 195 / 1875 ,    Train loss: 0.456, accumulated average loss: 0.746 ##############################
# ########################### Epoch: 0 , --  batch: 196 / 1875 ,    Train loss: 0.398, accumulated average loss: 0.745 ##############################
# ########################### Epoch: 0 , --  batch: 197 / 1875 ,    Train loss: 0.299, accumulated average loss: 0.742 ##############################
# ########################### Epoch: 0 , --  batch: 198 / 1875 ,    Train loss: 0.290, accumulated average loss: 0.740 ##############################
# ########################### Epoch: 0 , --  batch: 199 / 1875 ,    Train loss: 0.295, accumulated average loss: 0.738 ##############################
# ########################### Epoch: 0 , --  batch: 200 / 1875 ,    Train loss: 0.565, accumulated average loss: 0.737 ##############################
# ########################### Epoch: 0 , --  batch: 201 / 1875 ,    Train loss: 0.577, accumulated average loss: 0.736 ##############################
# ########################### Epoch: 0 , --  batch: 202 / 1875 ,    Train loss: 0.432, accumulated average loss: 0.735 ##############################
# ########################### Epoch: 0 , --  batch: 203 / 1875 ,    Train loss: 0.347, accumulated average loss: 0.733 ##############################
# ########################### Epoch: 0 , --  batch: 204 / 1875 ,    Train loss: 0.517, accumulated average loss: 0.732 ##############################
# ########################### Epoch: 0 , --  batch: 205 / 1875 ,    Train loss: 0.597, accumulated average loss: 0.731 ##############################
# ########################### Epoch: 0 , --  batch: 206 / 1875 ,    Train loss: 0.317, accumulated average loss: 0.729 ##############################
# ########################### Epoch: 0 , --  batch: 207 / 1875 ,    Train loss: 0.545, accumulated average loss: 0.728 ##############################
# ########################### Epoch: 0 , --  batch: 208 / 1875 ,    Train loss: 0.358, accumulated average loss: 0.727 ##############################
# ########################### Epoch: 0 , --  batch: 209 / 1875 ,    Train loss: 0.318, accumulated average loss: 0.725 ##############################
# ########################### Epoch: 0 , --  batch: 210 / 1875 ,    Train loss: 0.686, accumulated average loss: 0.724 ##############################
# ########################### Epoch: 0 , --  batch: 211 / 1875 ,    Train loss: 0.262, accumulated average loss: 0.722 ##############################
# ########################### Epoch: 0 , --  batch: 212 / 1875 ,    Train loss: 0.421, accumulated average loss: 0.721 ##############################
# ########################### Epoch: 0 , --  batch: 213 / 1875 ,    Train loss: 0.315, accumulated average loss: 0.719 ##############################
# ########################### Epoch: 0 , --  batch: 214 / 1875 ,    Train loss: 0.935, accumulated average loss: 0.720 ##############################
# ########################### Epoch: 0 , --  batch: 215 / 1875 ,    Train loss: 0.500, accumulated average loss: 0.719 ##############################
# ########################### Epoch: 0 , --  batch: 216 / 1875 ,    Train loss: 0.868, accumulated average loss: 0.720 ##############################
# ########################### Epoch: 0 , --  batch: 217 / 1875 ,    Train loss: 0.673, accumulated average loss: 0.719 ##############################
# ########################### Epoch: 0 , --  batch: 218 / 1875 ,    Train loss: 0.502, accumulated average loss: 0.718 ##############################
# ########################### Epoch: 0 , --  batch: 219 / 1875 ,    Train loss: 0.407, accumulated average loss: 0.717 ##############################
# ########################### Epoch: 0 , --  batch: 220 / 1875 ,    Train loss: 0.427, accumulated average loss: 0.716 ##############################
# ########################### Epoch: 0 , --  batch: 221 / 1875 ,    Train loss: 0.362, accumulated average loss: 0.714 ##############################
# ########################### Epoch: 0 , --  batch: 222 / 1875 ,    Train loss: 0.834, accumulated average loss: 0.715 ##############################
# ########################### Epoch: 0 , --  batch: 223 / 1875 ,    Train loss: 0.515, accumulated average loss: 0.714 ##############################
# ########################### Epoch: 0 , --  batch: 224 / 1875 ,    Train loss: 0.555, accumulated average loss: 0.713 ##############################
# ########################### Epoch: 0 , --  batch: 225 / 1875 ,    Train loss: 0.673, accumulated average loss: 0.713 ##############################
# ########################### Epoch: 0 , --  batch: 226 / 1875 ,    Train loss: 0.445, accumulated average loss: 0.712 ##############################
# ########################### Epoch: 0 , --  batch: 227 / 1875 ,    Train loss: 0.634, accumulated average loss: 0.711 ##############################
# ########################### Epoch: 0 , --  batch: 228 / 1875 ,    Train loss: 0.574, accumulated average loss: 0.711 ##############################
# ########################### Epoch: 0 , --  batch: 229 / 1875 ,    Train loss: 0.301, accumulated average loss: 0.709 ##############################
# ########################### Epoch: 0 , --  batch: 230 / 1875 ,    Train loss: 0.284, accumulated average loss: 0.707 ##############################
# ########################### Epoch: 0 , --  batch: 231 / 1875 ,    Train loss: 0.493, accumulated average loss: 0.706 ##############################
# ########################### Epoch: 0 , --  batch: 232 / 1875 ,    Train loss: 0.414, accumulated average loss: 0.705 ##############################
# ########################### Epoch: 0 , --  batch: 233 / 1875 ,    Train loss: 0.154, accumulated average loss: 0.703 ##############################
# ########################### Epoch: 0 , --  batch: 234 / 1875 ,    Train loss: 0.331, accumulated average loss: 0.701 ##############################
# ########################### Epoch: 0 , --  batch: 235 / 1875 ,    Train loss: 0.683, accumulated average loss: 0.701 ##############################
# ########################### Epoch: 0 , --  batch: 236 / 1875 ,    Train loss: 0.263, accumulated average loss: 0.699 ##############################
# ########################### Epoch: 0 , --  batch: 237 / 1875 ,    Train loss: 0.386, accumulated average loss: 0.698 ##############################
# ########################### Epoch: 0 , --  batch: 238 / 1875 ,    Train loss: 0.690, accumulated average loss: 0.698 ##############################
# ########################### Epoch: 0 , --  batch: 239 / 1875 ,    Train loss: 0.530, accumulated average loss: 0.697 ##############################
# ########################### Epoch: 0 , --  batch: 240 / 1875 ,    Train loss: 0.918, accumulated average loss: 0.698 ##############################
# ########################### Epoch: 0 , --  batch: 241 / 1875 ,    Train loss: 0.435, accumulated average loss: 0.697 ##############################
# ########################### Epoch: 0 , --  batch: 242 / 1875 ,    Train loss: 0.228, accumulated average loss: 0.695 ##############################
# ########################### Epoch: 0 , --  batch: 243 / 1875 ,    Train loss: 0.173, accumulated average loss: 0.693 ##############################
# ########################### Epoch: 0 , --  batch: 244 / 1875 ,    Train loss: 0.232, accumulated average loss: 0.691 ##############################
# ########################### Epoch: 0 , --  batch: 245 / 1875 ,    Train loss: 0.872, accumulated average loss: 0.692 ##############################
# ########################### Epoch: 0 , --  batch: 246 / 1875 ,    Train loss: 0.345, accumulated average loss: 0.690 ##############################
# ########################### Epoch: 0 , --  batch: 247 / 1875 ,    Train loss: 0.254, accumulated average loss: 0.688 ##############################
# ########################### Epoch: 0 , --  batch: 248 / 1875 ,    Train loss: 0.426, accumulated average loss: 0.687 ##############################
# ########################### Epoch: 0 , --  batch: 249 / 1875 ,    Train loss: 0.344, accumulated average loss: 0.686 ##############################
# ########################### Epoch: 0 , --  batch: 250 / 1875 ,    Train loss: 0.819, accumulated average loss: 0.687 ##############################
# ########################### Epoch: 0 , --  batch: 251 / 1875 ,    Train loss: 0.548, accumulated average loss: 0.686 ##############################
# ########################### Epoch: 0 , --  batch: 252 / 1875 ,    Train loss: 0.265, accumulated average loss: 0.684 ##############################
# ########################### Epoch: 0 , --  batch: 253 / 1875 ,    Train loss: 0.451, accumulated average loss: 0.683 ##############################
# ########################### Epoch: 0 , --  batch: 254 / 1875 ,    Train loss: 0.501, accumulated average loss: 0.683 ##############################
# ########################### Epoch: 0 , --  batch: 255 / 1875 ,    Train loss: 0.701, accumulated average loss: 0.683 ##############################
# ########################### Epoch: 0 , --  batch: 256 / 1875 ,    Train loss: 0.419, accumulated average loss: 0.682 ##############################
# ########################### Epoch: 0 , --  batch: 257 / 1875 ,    Train loss: 0.441, accumulated average loss: 0.681 ##############################
# ########################### Epoch: 0 , --  batch: 258 / 1875 ,    Train loss: 0.379, accumulated average loss: 0.680 ##############################
# ########################### Epoch: 0 , --  batch: 259 / 1875 ,    Train loss: 0.281, accumulated average loss: 0.678 ##############################
# ########################### Epoch: 0 , --  batch: 260 / 1875 ,    Train loss: 0.656, accumulated average loss: 0.678 ##############################
# ########################### Epoch: 0 , --  batch: 261 / 1875 ,    Train loss: 0.326, accumulated average loss: 0.677 ##############################
# ########################### Epoch: 0 , --  batch: 262 / 1875 ,    Train loss: 0.513, accumulated average loss: 0.676 ##############################
# ########################### Epoch: 0 , --  batch: 263 / 1875 ,    Train loss: 0.258, accumulated average loss: 0.674 ##############################
# ########################### Epoch: 0 , --  batch: 264 / 1875 ,    Train loss: 0.385, accumulated average loss: 0.673 ##############################
# ########################### Epoch: 0 , --  batch: 265 / 1875 ,    Train loss: 0.438, accumulated average loss: 0.673 ##############################
# ########################### Epoch: 0 , --  batch: 266 / 1875 ,    Train loss: 0.725, accumulated average loss: 0.673 ##############################
# ########################### Epoch: 0 , --  batch: 267 / 1875 ,    Train loss: 0.339, accumulated average loss: 0.671 ##############################
# ########################### Epoch: 0 , --  batch: 268 / 1875 ,    Train loss: 0.303, accumulated average loss: 0.670 ##############################
# ########################### Epoch: 0 , --  batch: 269 / 1875 ,    Train loss: 0.646, accumulated average loss: 0.670 ##############################
# ########################### Epoch: 0 , --  batch: 270 / 1875 ,    Train loss: 0.610, accumulated average loss: 0.670 ##############################
# ########################### Epoch: 0 , --  batch: 271 / 1875 ,    Train loss: 0.273, accumulated average loss: 0.668 ##############################
# ########################### Epoch: 0 , --  batch: 272 / 1875 ,    Train loss: 0.827, accumulated average loss: 0.669 ##############################
# ########################### Epoch: 0 , --  batch: 273 / 1875 ,    Train loss: 0.657, accumulated average loss: 0.669 ##############################
# ########################### Epoch: 0 , --  batch: 274 / 1875 ,    Train loss: 0.536, accumulated average loss: 0.668 ##############################
# ########################### Epoch: 0 , --  batch: 275 / 1875 ,    Train loss: 0.586, accumulated average loss: 0.668 ##############################
# ########################### Epoch: 0 , --  batch: 276 / 1875 ,    Train loss: 0.500, accumulated average loss: 0.667 ##############################
# ########################### Epoch: 0 , --  batch: 277 / 1875 ,    Train loss: 0.289, accumulated average loss: 0.666 ##############################
# ########################### Epoch: 0 , --  batch: 278 / 1875 ,    Train loss: 0.270, accumulated average loss: 0.665 ##############################
# ########################### Epoch: 0 , --  batch: 279 / 1875 ,    Train loss: 0.404, accumulated average loss: 0.664 ##############################
# ########################### Epoch: 0 , --  batch: 280 / 1875 ,    Train loss: 0.314, accumulated average loss: 0.663 ##############################
# ########################### Epoch: 0 , --  batch: 281 / 1875 ,    Train loss: 0.543, accumulated average loss: 0.662 ##############################
# ########################### Epoch: 0 , --  batch: 282 / 1875 ,    Train loss: 0.495, accumulated average loss: 0.661 ##############################
# ########################### Epoch: 0 , --  batch: 283 / 1875 ,    Train loss: 0.331, accumulated average loss: 0.660 ##############################
# ########################### Epoch: 0 , --  batch: 284 / 1875 ,    Train loss: 0.773, accumulated average loss: 0.661 ##############################
# ########################### Epoch: 0 , --  batch: 285 / 1875 ,    Train loss: 0.449, accumulated average loss: 0.660 ##############################
# ########################### Epoch: 0 , --  batch: 286 / 1875 ,    Train loss: 0.466, accumulated average loss: 0.659 ##############################
# ########################### Epoch: 0 , --  batch: 287 / 1875 ,    Train loss: 0.258, accumulated average loss: 0.658 ##############################
# ########################### Epoch: 0 , --  batch: 288 / 1875 ,    Train loss: 0.366, accumulated average loss: 0.657 ##############################
# ########################### Epoch: 0 , --  batch: 289 / 1875 ,    Train loss: 0.553, accumulated average loss: 0.657 ##############################
# ########################### Epoch: 0 , --  batch: 290 / 1875 ,    Train loss: 0.649, accumulated average loss: 0.657 ##############################
# ########################### Epoch: 0 , --  batch: 291 / 1875 ,    Train loss: 0.638, accumulated average loss: 0.656 ##############################
# ########################### Epoch: 0 , --  batch: 292 / 1875 ,    Train loss: 0.150, accumulated average loss: 0.655 ##############################
# ########################### Epoch: 0 , --  batch: 293 / 1875 ,    Train loss: 0.670, accumulated average loss: 0.655 ##############################
# ########################### Epoch: 0 , --  batch: 294 / 1875 ,    Train loss: 0.306, accumulated average loss: 0.654 ##############################
# ########################### Epoch: 0 , --  batch: 295 / 1875 ,    Train loss: 0.237, accumulated average loss: 0.652 ##############################
# ########################### Epoch: 0 , --  batch: 296 / 1875 ,    Train loss: 0.309, accumulated average loss: 0.651 ##############################
# ########################### Epoch: 0 , --  batch: 297 / 1875 ,    Train loss: 0.502, accumulated average loss: 0.651 ##############################
# ########################### Epoch: 0 , --  batch: 298 / 1875 ,    Train loss: 0.274, accumulated average loss: 0.649 ##############################
# ########################### Epoch: 0 , --  batch: 299 / 1875 ,    Train loss: 0.167, accumulated average loss: 0.648 ##############################
# ########################### Epoch: 0 , --  batch: 300 / 1875 ,    Train loss: 0.353, accumulated average loss: 0.647 ##############################
# ########################### Epoch: 0 , --  batch: 301 / 1875 ,    Train loss: 0.421, accumulated average loss: 0.646 ##############################
# ########################### Epoch: 0 , --  batch: 302 / 1875 ,    Train loss: 0.601, accumulated average loss: 0.646 ##############################
# ########################### Epoch: 0 , --  batch: 303 / 1875 ,    Train loss: 0.462, accumulated average loss: 0.645 ##############################
# ########################### Epoch: 0 , --  batch: 304 / 1875 ,    Train loss: 0.182, accumulated average loss: 0.644 ##############################
# ########################### Epoch: 0 , --  batch: 305 / 1875 ,    Train loss: 0.699, accumulated average loss: 0.644 ##############################
# ########################### Epoch: 0 , --  batch: 306 / 1875 ,    Train loss: 0.373, accumulated average loss: 0.643 ##############################
# ########################### Epoch: 0 , --  batch: 307 / 1875 ,    Train loss: 0.386, accumulated average loss: 0.642 ##############################
# ########################### Epoch: 0 , --  batch: 308 / 1875 ,    Train loss: 0.606, accumulated average loss: 0.642 ##############################
# ########################### Epoch: 0 , --  batch: 309 / 1875 ,    Train loss: 0.453, accumulated average loss: 0.641 ##############################
# ########################### Epoch: 0 , --  batch: 310 / 1875 ,    Train loss: 0.246, accumulated average loss: 0.640 ##############################
# ########################### Epoch: 0 , --  batch: 311 / 1875 ,    Train loss: 0.395, accumulated average loss: 0.639 ##############################
# ########################### Epoch: 0 , --  batch: 312 / 1875 ,    Train loss: 0.425, accumulated average loss: 0.639 ##############################
# ########################### Epoch: 0 , --  batch: 313 / 1875 ,    Train loss: 0.171, accumulated average loss: 0.637 ##############################
# ########################### Epoch: 0 , --  batch: 314 / 1875 ,    Train loss: 0.531, accumulated average loss: 0.637 ##############################
# ########################### Epoch: 0 , --  batch: 315 / 1875 ,    Train loss: 0.436, accumulated average loss: 0.636 ##############################
# ########################### Epoch: 0 , --  batch: 316 / 1875 ,    Train loss: 0.336, accumulated average loss: 0.635 ##############################
# ########################### Epoch: 0 , --  batch: 317 / 1875 ,    Train loss: 0.233, accumulated average loss: 0.634 ##############################
# ########################### Epoch: 0 , --  batch: 318 / 1875 ,    Train loss: 0.409, accumulated average loss: 0.633 ##############################
# ########################### Epoch: 0 , --  batch: 319 / 1875 ,    Train loss: 0.603, accumulated average loss: 0.633 ##############################
# ########################### Epoch: 0 , --  batch: 320 / 1875 ,    Train loss: 0.394, accumulated average loss: 0.632 ##############################
# ########################### Epoch: 0 , --  batch: 321 / 1875 ,    Train loss: 0.463, accumulated average loss: 0.632 ##############################
# ########################### Epoch: 0 , --  batch: 322 / 1875 ,    Train loss: 0.387, accumulated average loss: 0.631 ##############################
# ########################### Epoch: 0 , --  batch: 323 / 1875 ,    Train loss: 0.119, accumulated average loss: 0.630 ##############################
# ...
# ########################### Epoch: 4 , --  batch: 204 / 313 ,    Test loss: 0.159, accumulated average loss: 0.108 ##############################
# ########################### Epoch: 4 , --  batch: 205 / 313 ,    Test loss: 0.183, accumulated average loss: 0.108 ##############################
# ########################### Epoch: 4 , --  batch: 206 / 313 ,    Test loss: 0.061, accumulated average loss: 0.108 ##############################
# ########################### Epoch: 4 , --  batch: 207 / 313 ,    Test loss: 0.018, accumulated average loss: 0.108 ##############################
# ########################### Epoch: 4 , --  batch: 208 / 313 ,    Test loss: 0.017, accumulated average loss: 0.107 ##############################
# ########################### Epoch: 4 , --  batch: 209 / 313 ,    Test loss: 0.009, accumulated average loss: 0.107 ##############################
# ########################### Epoch: 4 , --  batch: 210 / 313 ,    Test loss: 0.357, accumulated average loss: 0.108 ##############################
# ########################### Epoch: 4 , --  batch: 211 / 313 ,    Test loss: 0.135, accumulated average loss: 0.108 ##############################
# ########################### Epoch: 4 , --  batch: 212 / 313 ,    Test loss: 0.176, accumulated average loss: 0.108 ##############################
# ########################### Epoch: 4 , --  batch: 213 / 313 ,    Test loss: 0.003, accumulated average loss: 0.108 ##############################
# ########################### Epoch: 4 , --  batch: 214 / 313 ,    Test loss: 0.020, accumulated average loss: 0.107 ##############################
# ########################### Epoch: 4 , --  batch: 215 / 313 ,    Test loss: 0.007, accumulated average loss: 0.107 ##############################
# ########################### Epoch: 4 , --  batch: 216 / 313 ,    Test loss: 0.055, accumulated average loss: 0.107 ##############################
# ########################### Epoch: 4 , --  batch: 217 / 313 ,    Test loss: 0.173, accumulated average loss: 0.107 ##############################
# ########################### Epoch: 4 , --  batch: 218 / 313 ,    Test loss: 0.126, accumulated average loss: 0.107 ##############################
# ########################### Epoch: 4 , --  batch: 219 / 313 ,    Test loss: 0.009, accumulated average loss: 0.107 ##############################
# ########################### Epoch: 4 , --  batch: 220 / 313 ,    Test loss: 0.011, accumulated average loss: 0.106 ##############################
# ########################### Epoch: 4 , --  batch: 221 / 313 ,    Test loss: 0.016, accumulated average loss: 0.106 ##############################
# ########################### Epoch: 4 , --  batch: 222 / 313 ,    Test loss: 0.559, accumulated average loss: 0.108 ##############################
# ########################### Epoch: 4 , --  batch: 223 / 313 ,    Test loss: 0.009, accumulated average loss: 0.107 ##############################
# ########################### Epoch: 4 , --  batch: 224 / 313 ,    Test loss: 0.134, accumulated average loss: 0.108 ##############################
# ########################### Epoch: 4 , --  batch: 225 / 313 ,    Test loss: 0.008, accumulated average loss: 0.107 ##############################
# ########################### Epoch: 4 , --  batch: 226 / 313 ,    Test loss: 0.116, accumulated average loss: 0.107 ##############################
# ########################### Epoch: 4 , --  batch: 227 / 313 ,    Test loss: 0.178, accumulated average loss: 0.107 ##############################
# ########################### Epoch: 4 , --  batch: 228 / 313 ,    Test loss: 0.218, accumulated average loss: 0.108 ##############################
# ########################### Epoch: 4 , --  batch: 229 / 313 ,    Test loss: 0.119, accumulated average loss: 0.108 ##############################
# ########################### Epoch: 4 , --  batch: 230 / 313 ,    Test loss: 0.201, accumulated average loss: 0.108 ##############################
# ########################### Epoch: 4 , --  batch: 231 / 313 ,    Test loss: 0.011, accumulated average loss: 0.108 ##############################
# ########################### Epoch: 4 , --  batch: 232 / 313 ,    Test loss: 0.013, accumulated average loss: 0.108 ##############################
# ########################### Epoch: 4 , --  batch: 233 / 313 ,    Test loss: 0.036, accumulated average loss: 0.107 ##############################
# ########################### Epoch: 4 , --  batch: 234 / 313 ,    Test loss: 0.043, accumulated average loss: 0.107 ##############################
# ########################### Epoch: 4 , --  batch: 235 / 313 ,    Test loss: 0.085, accumulated average loss: 0.107 ##############################
# ########################### Epoch: 4 , --  batch: 236 / 313 ,    Test loss: 0.138, accumulated average loss: 0.107 ##############################
# ########################### Epoch: 4 , --  batch: 237 / 313 ,    Test loss: 0.038, accumulated average loss: 0.107 ##############################
# ########################### Epoch: 4 , --  batch: 238 / 313 ,    Test loss: 0.090, accumulated average loss: 0.107 ##############################
# ########################### Epoch: 4 , --  batch: 239 / 313 ,    Test loss: 0.077, accumulated average loss: 0.107 ##############################
# ########################### Epoch: 4 , --  batch: 240 / 313 ,    Test loss: 0.012, accumulated average loss: 0.106 ##############################
# ########################### Epoch: 4 , --  batch: 241 / 313 ,    Test loss: 0.064, accumulated average loss: 0.106 ##############################
# ########################### Epoch: 4 , --  batch: 242 / 313 ,    Test loss: 0.034, accumulated average loss: 0.106 ##############################
# ########################### Epoch: 4 , --  batch: 243 / 313 ,    Test loss: 0.037, accumulated average loss: 0.105 ##############################
# ########################### Epoch: 4 , --  batch: 244 / 313 ,    Test loss: 0.307, accumulated average loss: 0.106 ##############################
# ########################### Epoch: 4 , --  batch: 245 / 313 ,    Test loss: 0.011, accumulated average loss: 0.106 ##############################
# ########################### Epoch: 4 , --  batch: 246 / 313 ,    Test loss: 0.191, accumulated average loss: 0.106 ##############################
# ########################### Epoch: 4 , --  batch: 247 / 313 ,    Test loss: 0.060, accumulated average loss: 0.106 ##############################
# ########################### Epoch: 4 , --  batch: 248 / 313 ,    Test loss: 0.219, accumulated average loss: 0.106 ##############################
# ########################### Epoch: 4 , --  batch: 249 / 313 ,    Test loss: 0.236, accumulated average loss: 0.107 ##############################
# ########################### Epoch: 4 , --  batch: 250 / 313 ,    Test loss: 0.122, accumulated average loss: 0.107 ##############################
# ########################### Epoch: 4 , --  batch: 251 / 313 ,    Test loss: 0.013, accumulated average loss: 0.107 ##############################
# ########################### Epoch: 4 , --  batch: 252 / 313 ,    Test loss: 0.072, accumulated average loss: 0.107 ##############################
# ########################### Epoch: 4 , --  batch: 253 / 313 ,    Test loss: 0.132, accumulated average loss: 0.107 ##############################
# ########################### Epoch: 4 , --  batch: 254 / 313 ,    Test loss: 0.066, accumulated average loss: 0.106 ##############################
# ########################### Epoch: 4 , --  batch: 255 / 313 ,    Test loss: 0.217, accumulated average loss: 0.107 ##############################
# ########################### Epoch: 4 , --  batch: 256 / 313 ,    Test loss: 0.030, accumulated average loss: 0.107 ##############################
# ########################### Epoch: 4 , --  batch: 257 / 313 ,    Test loss: 0.047, accumulated average loss: 0.106 ##############################
# ########################### Epoch: 4 , --  batch: 258 / 313 ,    Test loss: 0.223, accumulated average loss: 0.107 ##############################
# ########################### Epoch: 4 , --  batch: 259 / 313 ,    Test loss: 0.557, accumulated average loss: 0.109 ##############################
# ########################### Epoch: 4 , --  batch: 260 / 313 ,    Test loss: 0.086, accumulated average loss: 0.108 ##############################
# ########################### Epoch: 4 , --  batch: 261 / 313 ,    Test loss: 0.031, accumulated average loss: 0.108 ##############################
# ########################### Epoch: 4 , --  batch: 262 / 313 ,    Test loss: 0.322, accumulated average loss: 0.109 ##############################
# ########################### Epoch: 4 , --  batch: 263 / 313 ,    Test loss: 0.005, accumulated average loss: 0.109 ##############################
# ########################### Epoch: 4 , --  batch: 264 / 313 ,    Test loss: 0.003, accumulated average loss: 0.108 ##############################
# ########################### Epoch: 4 , --  batch: 265 / 313 ,    Test loss: 0.090, accumulated average loss: 0.108 ##############################
# ########################### Epoch: 4 , --  batch: 266 / 313 ,    Test loss: 0.089, accumulated average loss: 0.108 ##############################
# ########################### Epoch: 4 , --  batch: 267 / 313 ,    Test loss: 0.011, accumulated average loss: 0.108 ##############################
# ########################### Epoch: 4 , --  batch: 268 / 313 ,    Test loss: 0.011, accumulated average loss: 0.107 ##############################
# ########################### Epoch: 4 , --  batch: 269 / 313 ,    Test loss: 0.015, accumulated average loss: 0.107 ##############################
# ########################### Epoch: 4 , --  batch: 270 / 313 ,    Test loss: 0.023, accumulated average loss: 0.107 ##############################
# ########################### Epoch: 4 , --  batch: 271 / 313 ,    Test loss: 0.039, accumulated average loss: 0.106 ##############################
# ########################### Epoch: 4 , --  batch: 272 / 313 ,    Test loss: 0.197, accumulated average loss: 0.107 ##############################
# ########################### Epoch: 4 , --  batch: 273 / 313 ,    Test loss: 0.042, accumulated average loss: 0.107 ##############################
# ########################### Epoch: 4 , --  batch: 274 / 313 ,    Test loss: 0.043, accumulated average loss: 0.106 ##############################
# ########################### Epoch: 4 , --  batch: 275 / 313 ,    Test loss: 0.333, accumulated average loss: 0.107 ##############################
# ########################### Epoch: 4 , --  batch: 276 / 313 ,    Test loss: 0.015, accumulated average loss: 0.107 ##############################
# ########################### Epoch: 4 , --  batch: 277 / 313 ,    Test loss: 0.025, accumulated average loss: 0.106 ##############################
# ########################### Epoch: 4 , --  batch: 278 / 313 ,    Test loss: 0.009, accumulated average loss: 0.106 ##############################
# ########################### Epoch: 4 , --  batch: 279 / 313 ,    Test loss: 0.046, accumulated average loss: 0.106 ##############################
# ########################### Epoch: 4 , --  batch: 280 / 313 ,    Test loss: 0.174, accumulated average loss: 0.106 ##############################
# ########################### Epoch: 4 , --  batch: 281 / 313 ,    Test loss: 0.082, accumulated average loss: 0.106 ##############################
# ########################### Epoch: 4 , --  batch: 282 / 313 ,    Test loss: 0.479, accumulated average loss: 0.107 ##############################
# ########################### Epoch: 4 , --  batch: 283 / 313 ,    Test loss: 0.067, accumulated average loss: 0.107 ##############################
# ########################### Epoch: 4 , --  batch: 284 / 313 ,    Test loss: 0.219, accumulated average loss: 0.108 ##############################
# ########################### Epoch: 4 , --  batch: 285 / 313 ,    Test loss: 0.004, accumulated average loss: 0.107 ##############################
# ########################### Epoch: 4 , --  batch: 286 / 313 ,    Test loss: 0.023, accumulated average loss: 0.107 ##############################
# ########################### Epoch: 4 , --  batch: 287 / 313 ,    Test loss: 0.135, accumulated average loss: 0.107 ##############################
# ########################### Epoch: 4 , --  batch: 288 / 313 ,    Test loss: 0.225, accumulated average loss: 0.108 ##############################
# ########################### Epoch: 4 , --  batch: 289 / 313 ,    Test loss: 0.035, accumulated average loss: 0.107 ##############################
# ########################### Epoch: 4 , --  batch: 290 / 313 ,    Test loss: 0.112, accumulated average loss: 0.107 ##############################
# ########################### Epoch: 4 , --  batch: 291 / 313 ,    Test loss: 0.153, accumulated average loss: 0.107 ##############################
# ########################### Epoch: 4 , --  batch: 292 / 313 ,    Test loss: 0.016, accumulated average loss: 0.107 ##############################
# ########################### Epoch: 4 , --  batch: 293 / 313 ,    Test loss: 0.203, accumulated average loss: 0.107 ##############################
# ########################### Epoch: 4 , --  batch: 294 / 313 ,    Test loss: 0.188, accumulated average loss: 0.108 ##############################
# ########################### Epoch: 4 , --  batch: 295 / 313 ,    Test loss: 0.052, accumulated average loss: 0.108 ##############################
# ########################### Epoch: 4 , --  batch: 296 / 313 ,    Test loss: 0.021, accumulated average loss: 0.107 ##############################
# ########################### Epoch: 4 , --  batch: 297 / 313 ,    Test loss: 0.078, accumulated average loss: 0.107 ##############################
# ########################### Epoch: 4 , --  batch: 298 / 313 ,    Test loss: 0.182, accumulated average loss: 0.107 ##############################
# ########################### Epoch: 4 , --  batch: 299 / 313 ,    Test loss: 0.048, accumulated average loss: 0.107 ##############################
# ########################### Epoch: 4 , --  batch: 300 / 313 ,    Test loss: 0.018, accumulated average loss: 0.107 ##############################
# ########################### Epoch: 4 , --  batch: 301 / 313 ,    Test loss: 0.042, accumulated average loss: 0.107 ##############################
# ########################### Epoch: 4 , --  batch: 302 / 313 ,    Test loss: 0.003, accumulated average loss: 0.106 ##############################
# ########################### Epoch: 4 , --  batch: 303 / 313 ,    Test loss: 0.031, accumulated average loss: 0.106 ##############################
# ########################### Epoch: 4 , --  batch: 304 / 313 ,    Test loss: 0.050, accumulated average loss: 0.106 ##############################
# ########################### Epoch: 4 , --  batch: 305 / 313 ,    Test loss: 0.362, accumulated average loss: 0.107 ##############################
# ########################### Epoch: 4 , --  batch: 306 / 313 ,    Test loss: 0.013, accumulated average loss: 0.106 ##############################
# ########################### Epoch: 4 , --  batch: 307 / 313 ,    Test loss: 0.024, accumulated average loss: 0.106 ##############################
# ########################### Epoch: 4 , --  batch: 308 / 313 ,    Test loss: 0.410, accumulated average loss: 0.107 ##############################
# ########################### Epoch: 4 , --  batch: 309 / 313 ,    Test loss: 0.052, accumulated average loss: 0.107 ##############################
# ########################### Epoch: 4 , --  batch: 310 / 313 ,    Test loss: 0.014, accumulated average loss: 0.107 ##############################
# ########################### Epoch: 4 , --  batch: 311 / 313 ,    Test loss: 0.059, accumulated average loss: 0.107 ##############################
# ########################### Epoch: 4 , --  batch: 312 / 313 ,    Test loss: 0.025, accumulated average loss: 0.106 ##############################
